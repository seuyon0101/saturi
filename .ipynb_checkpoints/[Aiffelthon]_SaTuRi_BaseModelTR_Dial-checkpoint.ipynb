# %%
import tensorflow as tf
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt

import time
import re
import os
import io


# from tqdm import tqdm_notebook 
from tqdm.notebook import tqdm 
import random

import sentencepiece as spm
from konlpy.tag import Mecab

# %% [markdown]
# # Step 1. 데이터 다운로드

# %%
# train data load
data_dir = os.getenv('HOME')+'/aiffel/aiffelthon/data'
data_path = data_dir+"/dataset_full_translated_en_ko_0221_last_added_0221_12h.csv"
full_data = pd.read_csv(data_path)
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678355 entries, 0 to 678354
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  678355 non-null  int64
#  1   text        678354 non-null  object
#  2   dial        678355 non-null  object
#  3   reg         678355 non-null  object
#  4   eng         678355 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 25.9+ MB

# %%
full_data.head()
# Out:
#    Unnamed: 0                                   text  \
# 0           0                          생각이 쪼금씩 바뀌더라고
# 1           1                어 알겠는가 외국인들이 그래도 잘 적응하고
# 2           2               아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3           3  보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           4           약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                    dial reg  \
# 0                         생각이 쪼금씩 바뀌드라고  jd
# 1               어 알겄는가 외국인들이 그래도 잘 적응하고  jd
# 2             아으 갑자기 예전에 맹장 뜯은 게 생각난디야.  jd
# 3  보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.  jd
# 4           약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도  jd
#
#                                                  eng
# 0                 I've changed my mind a little bit.
# 1    You know what? Foreigners still get used to it.
# 2  All of a sudden, I think I've ripped off my ap...
# 3  I have a lot of ideas about getting older in a...
# 4        It's a little bit of a tastey, but still...

# %%
full_data.isnull().sum()
# Out:
# Unnamed: 0    0
# text          1
# dial          0
# reg           0
# eng           0
# dtype: int64

# %%
def del_null_dupl(data):
    data=data.dropna(axis=0)
    data=data[~data.duplicated(subset=['text','dial','reg','eng'], keep= 'first')]
    data=data.reset_index(drop=True)# index reset하기 - 기존 index 제거 O
    return data

# %%
full_data=del_null_dupl(full_data) # ['text', 'dial', 'reg', 'eng'])

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678354 entries, 0 to 678353
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  678354 non-null  int64
#  1   text        678354 non-null  object
#  2   dial        678354 non-null  object
#  3   reg         678354 non-null  object
#  4   eng         678354 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 25.9+ MB

# %%
full_data['eng_length'] = full_data['eng'].apply(lambda x : len(str(x).split()))
full_data['dial_length'] = full_data['dial'].apply(lambda x : len(str(x).split()))
full_data['eng_c_length'] = full_data['eng'].apply(lambda x : len(str(x)))
full_data['dial_c_length'] = full_data['dial'].apply(lambda x : len(str(x)))

# %%
full_data.head()
# Out:
#    Unnamed: 0                                   text  \
# 0           0                          생각이 쪼금씩 바뀌더라고
# 1           1                어 알겠는가 외국인들이 그래도 잘 적응하고
# 2           2               아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3           3  보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4           4           약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#
#                                    dial reg  \
# 0                         생각이 쪼금씩 바뀌드라고  jd
# 1               어 알겄는가 외국인들이 그래도 잘 적응하고  jd
# 2             아으 갑자기 예전에 맹장 뜯은 게 생각난디야.  jd
# 3  보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.  jd
# 4           약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도  jd
#
#                                                  eng  eng_length  dial_length  \
# 0                 I've changed my mind a little bit.           7            3
# 1    You know what? Foreigners still get used to it.           9            6
# 2  All of a sudden, I think I've ripped off my ap...          12            7
# 3  I have a lot of ideas about getting older in a...          14           11
# 4        It's a little bit of a tastey, but still...           9            9
#
#    eng_c_length  dial_c_length
# 0            34             13
# 1            47             23
# 2            60             25
# 3            66             36
# 4            43             27

# %%
regs = ['jj', 'jd', 'gs', 'cc', 'kw']

for reg in regs:
    count = full_data['dial'][full_data['reg']==reg].count()
    print(f'Dial_{reg} :', count)
# Out:
# Dial_jj : 157837
# Dial_jd : 136086
# Dial_gs : 21268
# Dial_cc : 25504
# Dial_kw : 337659

# %%
full_data.groupby(full_data['reg'])['eng_length'].mean()
# Out:
# reg
# cc    17.937422
# gs    17.140587
# jd    14.756720
# jj    11.873559
# kw     9.547914
# Name: eng_length, dtype: float64

# %%
full_data.groupby(full_data['reg'])['dial_length'].mean()
# Out:
# reg
# cc    10.512390
# gs     9.867406
# jd     8.961524
# jj     6.454501
# kw     5.997832
# Name: dial_length, dtype: float64

# %%
eng_data = full_data[['eng', 'eng_length']]
eng_data
# Out:
#                                                       eng  eng_length
# 0                      I've changed my mind a little bit.           7
# 1         You know what? Foreigners still get used to it.           9
# 2       All of a sudden, I think I've ripped off my ap...          12
# 3       I have a lot of ideas about getting older in a...          14
# 4             It's a little bit of a tastey, but still...           9
# ...                                                   ...         ...
# 678349          But I'm the one who gives you everything.           8
# 678350      I'm hiding something that's disturbing to me.           7
# 678351  Do you want to eat the brine to keep me health...         260
# 678352  It's a mistake. It's all because I don't have ...          10
# 678353  I couldn't cry out loud on the street, "I love...          11
#
# [678354 rows x 2 columns]

# %%
dial_data = full_data[['reg', 'dial', 'dial_length']]
dial_data
# Out:
#        reg                                  dial  dial_length
# 0       jd                         생각이 쪼금씩 바뀌드라고            3
# 1       jd               어 알겄는가 외국인들이 그래도 잘 적응하고            6
# 2       jd             아으 갑자기 예전에 맹장 뜯은 게 생각난디야.            7
# 3       jd  보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.           11
# 4       jd           약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도            9
# ...     ..                                   ...          ...
# 678349  kw                 하지만 난 당신한테 전수 거는 놈이지.            6
# 678350  kw                    마음이 언짢은 것을 감추고 논다.            5
# 678351  kw               어머야라 내 몸 근강하자구 흑염솔 먹어요?            6
# 678352  kw                실수로 그른건데 다 내가 부족한 탓이제.            6
# 678353  kw   길에서 큰 소리기로 @이름1씨 사랑해요 라고 외칠 수는 없었지만            9
#
# [678354 rows x 3 columns]

# %%
full_data["reg_dial"] = "<" + full_data["reg"] +"> "+full_data["dial"]
full_data["reg_dial"]
# Out:
# 0                                <jd> 생각이 쪼금씩 바뀌드라고
# 1                      <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                    <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3         <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                  <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
#                             ...
# 678349                   <kw> 하지만 난 당신한테 전수 거는 놈이지.
# 678350                      <kw> 마음이 언짢은 것을 감추고 논다.
# 678351                 <kw> 어머야라 내 몸 근강하자구 흑염솔 먹어요?
# 678352                  <kw> 실수로 그른건데 다 내가 부족한 탓이제.
# 678353     <kw> 길에서 큰 소리기로 @이름1씨 사랑해요 라고 외칠 수는 없었지만
# Name: reg_dial, Length: 678354, dtype: object

# %%
full_data
# Out:
#         Unnamed: 0                                   text  \
# 0                0                          생각이 쪼금씩 바뀌더라고
# 1                1                어 알겠는가 외국인들이 그래도 잘 적응하고
# 2                2               아으 갑자기 예전에 맹장 뜯은 게 생각난다.
# 3                3  보면은 조금 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                4           약간 조금 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...            ...                                    ...
# 678349      379995                  하지만 난 당신한테 전부 거는 놈이지.
# 678350      379996                     마음이 언짢은 것을 숨기고 있다.
# 678351      379997                 아이구 내 몸 건강하자고 흑염솔 먹어요?
# 678352      379998                 실수로 그런건데 다 내가 부족한 탓이지.
# 678353      379999     길에서 큰 소리로 @이름1씨 사랑해요 라고 외칠 수는 없었지만
#
#                                         dial reg  \
# 0                              생각이 쪼금씩 바뀌드라고  jd
# 1                    어 알겄는가 외국인들이 그래도 잘 적응하고  jd
# 2                  아으 갑자기 예전에 맹장 뜯은 게 생각난디야.  jd
# 3       보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.  jd
# 4                약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도  jd
# ...                                      ...  ..
# 678349                 하지만 난 당신한테 전수 거는 놈이지.  kw
# 678350                    마음이 언짢은 것을 감추고 논다.  kw
# 678351               어머야라 내 몸 근강하자구 흑염솔 먹어요?  kw
# 678352                실수로 그른건데 다 내가 부족한 탓이제.  kw
# 678353   길에서 큰 소리기로 @이름1씨 사랑해요 라고 외칠 수는 없었지만  kw
#
#                                                       eng  eng_length  \
# 0                      I've changed my mind a little bit.           7
# 1         You know what? Foreigners still get used to it.           9
# 2       All of a sudden, I think I've ripped off my ap...          12
# 3       I have a lot of ideas about getting older in a...          14
# 4             It's a little bit of a tastey, but still...           9
# ...                                                   ...         ...
# 678349          But I'm the one who gives you everything.           8
# 678350      I'm hiding something that's disturbing to me.           7
# 678351  Do you want to eat the brine to keep me health...         260
# 678352  It's a mistake. It's all because I don't have ...          10
# 678353  I couldn't cry out loud on the street, "I love...          11
#
#         dial_length  eng_c_length  dial_c_length  \
# 0                 3            34             13
# 1                 6            47             23
# 2                 7            60             25
# 3                11            66             36
# 4                 9            43             27
# ...             ...           ...            ...
# 678349            6            41             21
# 678350            5            45             18
# 678351            6          1043             23
# 678352            6            53             22
# 678353            9            51             35
#
#                                          reg_dial
# 0                              <jd> 생각이 쪼금씩 바뀌드라고
# 1                    <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고
# 2                  <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야.
# 3       <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해요.
# 4                <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도
# ...                                           ...
# 678349                 <kw> 하지만 난 당신한테 전수 거는 놈이지.
# 678350                    <kw> 마음이 언짢은 것을 감추고 논다.
# 678351               <kw> 어머야라 내 몸 근강하자구 흑염솔 먹어요?
# 678352                <kw> 실수로 그른건데 다 내가 부족한 탓이제.
# 678353   <kw> 길에서 큰 소리기로 @이름1씨 사랑해요 라고 외칠 수는 없었지만
#
# [678354 rows x 10 columns]

# %%
# # 1. 모든 입력을 소문자로 변환합니다.
# # 2. 알파벳, 문장부호, 한글만 남기고 모두 제거합니다.
# # 3. 문장부호 양옆에 공백을 추가합니다.
# # 4. 문장 앞뒤의 불필요한 공백을 제거합니다.

# 특수 토큰의 인덱스를 아래와 동일하게 지정합니다.
# <PAD> : 0 / <BOS> : 1 / <EOS> : 2 / <UNK> : 3
# <jj> : 4 / <jd> : 5 / <gs> : 6 / <cc> : 7 / <kw> : 8

def preprocess_sentence(sentence, s_token=False, e_token=False):

    sentence = sentence.lower()
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    sentence = re.sub(r"[^a-zA-Z?.!<>가-힣ㄱ-ㅎㅏ-ㅣ]+", " ", sentence)
    sentence_del = re.search(r'(.+)\1{3,}', sentence)
    sentence = sentence.strip()

    if s_token:
        sentence = ' <str> ' + sentence 
        
    if e_token:
        sentence += ' <end>'

    
    return sentence

# %%
regs = ['jj', 'jd', 'gs', 'cc', 'kw']

for reg in regs:
    count = full_data['dial'][full_data['reg']==reg].count()
    print(f'Dial_{reg} :', count)
# Out:
# Dial_jj : 157837
# Dial_jd : 136086
# Dial_gs : 21268
# Dial_cc : 25504
# Dial_kw : 337659

# %%
# encoder corpus
enc_corpus = full_data['eng'].apply(lambda x : preprocess_sentence(x)).sort_index()

# %%
enc_corpus
# Out:
# 0                       i ve changed my mind a little bit .
# 1         you know what ? foreigners still get used to it .
# 2         all of a sudden i think i ve ripped off my app...
# 3         i have a lot of ideas about getting older in a...
# 4             it s a little bit of a tastey but still . . .
#                                 ...
# 678349           but i m the one who gives you everything .
# 678350       i m hiding something that s disturbing to me .
# 678351    do you want to eat the brine to keep me health...
# 678352    it s a mistake . it s all because i don t have...
# 678353     i couldn t cry out loud on the street i love you
# Name: eng, Length: 678354, dtype: object

# %%
# enc_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in enc_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(enc_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in enc_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 0
# 문장의 최장 길이: 2714
# 문장의 평균 길이: 56

# %%
dirt_data = []
enc_corpus = []
for i in range(len(enc_corpus)) :
    length = len(enc_corpus[i])
    match = re.search(r'(.+)\1{3,}',enc_corpus[i]) # 반복적으로 나오는 단어가 있는 문장 삭제
    if match or length == 0 :
        dirt_data.append(i)
    else :
        enc_corpus.append(enc_corpus[i])

# %%
enc_corpus
# Out:
# []

# %%
# enc_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in enc_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(enc_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in enc_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 999
# 문장의 최장 길이: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_557/2237714818.py in <module>
#      14 print("문장의 최단 길이:", min_len)
#      15 print("문장의 최장 길이:", max_len)
# ---> 16 print("문장의 평균 길이:", sum_len // len(enc_corpus))
#      17
#      18 sentence_length = np.zeros((max_len), dtype=int)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
dec_corpus = full_data['reg_dial'].apply(lambda x : preprocess_sentence(x, s_token=True, e_token=True)).sort_index()

# %%
dec_corpus
# Out:
# 0                            <str> <jd> 생각이 쪼금씩 바뀌드라고 <end>
# 1                  <str> <jd> 어 알겄는가 외국인들이 그래도 잘 적응하고 <end>
# 2               <str> <jd> 아으 갑자기 예전에 맹장 뜯은 게 생각난디야 . <end>
# 3          <str> <jd> 보면은 쫌 품위 있게 나이 들어가야 되겠단 생각을 참 많이 해...
# 4              <str> <jd> 약간 쫌 약간 맛이 쪼끔 거시기 하긴 한데 그래도 <end>
#                                 ...
# 678349              <str> <kw> 하지만 난 당신한테 전수 거는 놈이지 . <end>
# 678350                 <str> <kw> 마음이 언짢은 것을 감추고 논다 . <end>
# 678351            <str> <kw> 어머야라 내 몸 근강하자구 흑염솔 먹어요 ? <end>
# 678352             <str> <kw> 실수로 그른건데 다 내가 부족한 탓이제 . <end>
# 678353     <str> <kw> 길에서 큰 소리기로 이름 씨 사랑해요 라고 외칠 수는 없었지만...
# Name: reg_dial, Length: 678354, dtype: object

# %%
# dec_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in dec_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(dec_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in dec_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()
# Out:
# 문장의 최단 길이: 19
# 문장의 최장 길이: 234
# 문장의 평균 길이: 42

# %% [markdown]
# # Step 2. 데이터 정제 및 토큰화

# %%
# Train 데이터 정제 및 토큰화
def clean_corpus(enc_corpus, dec_corpus):

    assert len(enc_corpus) == len(dec_corpus) # enc_corpus, dec_corpus가 같은 갯수라는 것을 검증받기 위해 적용

    cleaned_corpus = list(set(zip(enc_corpus, dec_corpus)))  # 중복된 데이터 제거
    
    return cleaned_corpus

cleaned_corpus = clean_corpus(enc_corpus, dec_corpus)
len(cleaned_corpus)
cleaned_corpus
# Out:
# [('it s not my country s name corian .',
#   ' <str> <kw> 그 털이 쫌 덜 빠지는 게 우리나라 그 코리안 숏이라고 뭔 뭐드라 이름 <end>'),
#  ('no but the middle three are baek and ji baek eightysix',
#   ' <str> <jj> 아니 그런데 중 삼이 백 지 백 백팔십삼 이라 ? <end>'),
#  ('i m looking at the time and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it and i m looking at it .',
#   ' <str> <jj> 시간이 보난 웃음 <end>'),
#  ('meat', ' <str> <jj> 괴기 괴기 <end>'),
#  ('but my mom was like this from to',
#   ' <str> <jd> 근데 엄마가 백 삼십에서 구십 막 이러드라고 인제 <end>'),
#  ('you really are .', ' <str> <kw> 증말 씨 . <end>'),
#  ('i ve got a kid .', ' <str> <kw> 이름아 마옴을 쪼매만 누구려 봐 애가 있잖어 . <end>'),
#  ('what does a strong force almost mean by justice ?',
#   ' <str> <gs> 힘이 쎄다는 거의 정의가 뭘 말하는 거죠 ? <end>'),
#  ('actually we dont go to eat very often so we dont know either',
#   ' <str> <jj> 사실 우리는 막 먹으러 가 잘 안 가부난이 나도 우린 잘 모르게신디 <end>'),
#  ('i tried it i tried it but i didnt', ' <str> <jj> 해봤덴 . 해봐신디 안된덴 . <end>'),
#  ('that s just the way it s supposed to be .', ' <str> <jj> 그거 딱 해그냉 <end>'),
#  ('a little bit . i ve never seen that drug before .',
#   ' <str> <gs> 약간 쫌 저는 이제 그 약을 처음 봤는데 <end>'),
#  ('i didn t find it yet . i thought it was like this .',
#   ' <str> <gs> 아직 못 찾았따 이런 걸로 알고 있었는데 <end>'),
#  ('you can t eat chicken . you can t eat chicken .',
#   ' <str> <jj> 독괴기 못먹어진댕하멍 독죽만 <end>'),
#  ('you didn t even introduce me to her for being nice .',
#   ' <str> <kw> 선 봐서 겨론한다고 소개팅도 안하민서 <end>'),
#  ('mother when did you get here ?', ' <str> <kw> 운제 오셨어요 어멍이 . <end>'),
#  ('the wound is too deep .', ' <str> <kw> 상처가 너무 기퍼 . <end>'),
#  ('how many times did i ask you to get an insurance ?',
#   ' <str> <kw> 그때 내가 너한테 보험 하내기 들어달라고 얼매나 사정사정했나 ? <end>'),
#  ('do i care ?', ' <str> <kw> 내가 신겡 쓰이니 ? <end>'),
#  ('of course you can understand that .',
#   ' <str> <kw> 물론 충부이 이해할 수 있습니다 . <end>'),
#  ('i ll eat fast .', ' <str> <kw> 날래 밥 먹을게 . <end>'),
#  ('i ve been working on my employees computers and i found something interesting .',
#   ' <str> <kw> 직원들 컴퓨터 사용 실태를 조사해 왔는데 한 아지 흥미로운 사실을 발견했어요 . <end>'),
#  ('but you re still my brother when you get back',
#   ' <str> <jj> 그때 되가면 아 그래도 형 그래도 내 동생 하면서 예 <end>'),
#  ('becoming a cop taking down the thugs .',
#   ' <str> <kw> 경찰이 돼서 깡패들을 잡어디리다 . <end>'),
#  ('that s not a funny movie .', ' <str> <jj> 그건 좀 웃긴 영화 아닌 <end>'),
#  ('if it s next summer we ll have to change the car or we ll have to change the car or we ll have to change the car .',
#   ' <str> <jd> 어차피 내년 여름 되믄은 차를 바꿔 폐차하든지 바꾸든지 해야 되니까 <end>'),
#  ('i really wanted to go there and the northern europe that you said was going too far .',
#   ' <str> <gs> 그 거기 진짜 가보고 싶었고 니가 말한 북유럽도 너무 가고 <end>'),
#  ('yeah it s okay mom .', ' <str> <kw> 나 괜찮아요 어머이 . <end>'),
#  ('she s living alone and you should ve told me .',
#   ' <str> <kw> 어머이가 혼재 살게 됐는데 진작에 나한테 말했어야 할 거 아냐 . <end>'),
#  ('its a little hiphop label now ambition records ever aom gni',
#   ' <str> <jd> 쫌 힙합 레이블이라 그러죠 이제 앰비션 레코즈나 그 에버 에이오엠지나 <end>'),
#  ('i always had to lie down on the bottom eat food and eat rice .',
#   ' <str> <kw> 그래가주구 항상 아랫목에 누우라 그러고 밥주구 밥 먹고 그랬거든요 그때는 <end>'),
#  ('that chanel wasn t mine .', ' <str> <jj> 그 샤넬 그것도 내 스탈 아니 . <end>'),
#  ('oh shit .', ' <str> <kw> 이란 제길 <end>'),
#  ('aren t you an idiot ?', ' <str> <kw> 너 진생이 아니야 ? <end>'),
#  ('i went to my late education and it was good in the late half but they said it was a little hard after i was put up with it .',
#   ' <str> <cc> 후반기 교육을 갔다 왔는데 후반기 땐 좋았는데 자대 배치받고 나서 쫌 많이 힘들었다 하더라고 <end>'),
#  ('don t put that stuff down for nothing .',
#   ' <str> <kw> 그 짐은 마구재비로 부르지 말아라 . <end>'),
#  ('it s not so good to go too far anywhere .',
#   ' <str> <kw> 어데든 너머 멀리 떠나는 건 별로 안좋아 . <end>'),
#  ('that s why i m spending as much money as i can just to make it simple .',
#   ' <str> <jd> 그런게 서슴 없드라고 그니까 돈을 번만큼 쓰는 거지 그냥 간단하게 간편하게 <end>'),
#  ('and then i started with the name and it s been making a lot of difference since then .',
#   ' <str> <jd> 그래갖고 그 때부터 이름이랑 같이 시작했는데 그때부터 이제 차이가 심하게 많이 났어 <end>'),
#  ('i m holding up because of .', ' <str> <kw> 저도 이름 이 때미에 저도 참는 겁니다 . <end>'),
#  ('do you buy a whetstone', ' <str> <jj> 신돌 사당 ? <end>'),
#  ('there are a lot of people who have just been missionaries in my country .',
#   ' <str> <jd> 막 우리나라에서 이렇게 선교사로 가신 분들이 쫌 많거든 . <end>'),
#  ('if you re good enough help me .',
#   ' <str> <jj> 잘 하기만 하면 옆에서 도와줍니다게 . <end>'),
#  ('do dogs have any genetic diseases like this ?',
#   ' <str> <jd> 강아지들도 먼가 유전적인 질환 이런 게 있나요 ? <end>'),
#  ('do you like him ? do you like him ?', ' <str> <jj> 그런 사람이 좋댄 공감 해 ? <end>'),
#  ('because the rice s falling there s no place to go to buy rice .',
#   ' <str> <jj> 쌀이 떨어지니까 여긴 쌀 사러 가는 데도 없지않으꽈 ? <end>'),
#  ('then when do you start ? maybe you ll start another week later .',
#   ' <str> <jj> 그럼 언제부터 시작하세요 하면 또 이 주 뒤에 시작 해야 될수도 인 <end>'),
#  ('the news comes before the drama so just wait a minute .',
#   ' <str> <kw> 드라마보다 뉴스가 먼처 나오니까 조금만 기다리렴 . <end>'),
#  ('i went to buy some new clothes .', ' <str> <kw> 새끄데기 옷 사러 갔어요 . <end>'),
#  ('momtha you sent it to the red this time',
#   ' <str> <jj> 어머니 요번에 적갈 보내수께 <end>'),
#  ('don t give up . keep going .', ' <str> <kw> 페기 하지말고 질래 해 봐요 . <end>'),
#  ('i don t want to say anything more to my mom .',
#   ' <str> <kw> 아 인자 나 엄마한테 더 듣구 싶은 말두 하구 싶은 말두 없어요 . <end>'),
#  ('you have to do it you can do it with anyone you dont do that',
#   ' <str> <jj> 해야주게 . 아무 사람이라도 하믄 되나 . 그런 건 안 햄잖아 . <end>'),
#  ('and theres a fashion king that king of fashion was a hit so it was also released in the movie',
#   ' <str> <jd> 그리고 또 막 패션왕 이런 거 있자녀 그 패션왕이 엄청 흥행했자녀 그래가지고 막 그 영화로도 나오고 <end>'),
#  ('it s fun to be a little bit more like a man .',
#   ' <str> <jj> 소나이도 호끔 영 게 것도 재미나주게 . <end>'),
#  ('i like it with it and i want you to cut it .',
#   ' <str> <kw> 그것으로 좋아요 그래구 이것을 다려 주세요 . <end>'),
#  ('i feel like whatever it is it s okay .',
#   ' <str> <kw> 우딴 상태가 되든 될 대루 되라는 기분이야 . <end>'),
#  ('every time you go you take the harpoon you take the harpoon you take the harpoon you take the harpoon and now you do it too ?',
#   ' <str> <jj> 갈 때마다 이제 작살을 가지고 가 작살 알아 작살 작살을 가지고 가가지고 이제 우럭이니 뭐니 그럼 고모도 그걸 해마씨 ? <end>'),
#  ('i think thats the technique of conversation so that the other person doesnt feel hurt while talking about some of the things i felt sorry for',
#   ' <str> <jd> 이거 또 이거 나 좀 아쉬웠던 부분들 조금 얘기하면서 이르케 상대방이 기분이 상하지 않게 그게 대화의 기술인 거 같애 . <end>'),
#  ('oh my the family is a civil servant so its okay its okay only the child is young and nice',
#   ' <str> <jj> 아이고 그 집안은 공무원 하 는 집안이여 괜찮다 괜찮다 아이만 어질고 착하 믄 됐져 <end>'),
#  ('no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no .',
#   ' <str> <kw> 아이 거래 이게 가락지라고 ? <end>'),
#  ('you can t do that .', ' <str> <kw> 낭반은 못 되는구만 . <end>'),
#  ('do you know how to do that ?', ' <str> <kw> 그른 것도 할 줄 아나 ? <end>'),
#  ('in the morning consciousness will return .',
#   ' <str> <kw> 아직이면 의식이 돌아올 거라고 합니다 . <end>'),
#  ('i want to go hang out with the kids a little bit .',
#   ' <str> <jd> 애들이랑 다 같이 쫌 놀러 가고 싶다 약간 그런 게 있지 . <end>'),
#  ('his humour is reaching a ripe place .',
#   ' <str> <kw> 그의 익살은 원숙한 경지에 이르고 논다 . <end>'),
#  ('i did the wrong thing .', ' <str> <cc> 내가 잘못 했디야 <end>'),
#  ('so you don t have to say that .', ' <str> <jj> 겅하니깐 그건 말 안하면 되지 <end>'),
#  ('you were forced to stay in the airfield .',
#   ' <str> <kw> 성이 강제로 비행장에 있었었지 . <end>'),
#  ('i can t walk . i can t walk . i can t walk .',
#   ' <str> <jj> 사라봉 가는 것도 헉헉대멍 나도 걷지 못허영 <end>'),
#  ('what are you doing there ?', ' <str> <kw> 거게서 뭐하세요 ? <end>'),
#  ('so you just say yes .', ' <str> <kw> 그래이까 당신은 처레미 그렇게 그러겠다고만 해 . <end>'),
#  ('i think it s the same thing .', ' <str> <jd> 똑같은 거 같애서 . <end>'),
#  ('saving isn t hard at all .', ' <str> <kw> 저축은 전예 하기 어려운 기 아니야 . <end>'),
#  ('and later someone came and said who s your sister ?',
#   ' <str> <jd> 나중에 어떤 사람이 와가꼬 누구 누나냐 하길래 맨날 가나지에 예 긍께 <end>'),
#  ('it s a little thick and it s a little thick and it s a little bit thick .',
#   ' <str> <kw> 매콤하고 쪼금 걸쭉하고 이런 <end>'),
#  ('how long are you really gonna do this ?',
#   ' <str> <kw> 엄만 진짜 운제까지 이러실 거예요 ? <end>'),
#  ('so you re mine too . mine mine .', ' <str> <kw> 그러이까 니도 내꺼야 내꺼 내꺼 . <end>'),
#  ('preliminary suffocation .', ' <str> <kw> 예비 헹부감으루 <end>'),
#  ('i wanted to take care of you a little bit but it was a little bit of a problem and i heard you say it .',
#   ' <str> <jd> 쫌 잘 챙겨주고 싶은데 그게 쪼끔 고민이었거든요 근데 말씀하시는 거 들어 보니까 <end>'),
#  ('i m boiling my ass .', ' <str> <kw> 나 이거 찌지개 끓어 넘잖아 . <end>'),
#  ('there s something like this .', ' <str> <jd> 이런 게 있드라고 . <end>'),
#  ('but what about lee zero ?', ' <str> <gs> 근데 리 제로는 어떤 내용이고 ? <end>'),
#  ('what happened to your brother ?', ' <str> <kw> 니 오빠한테 무신 일이 생긴 거야 . <end>'),
#  ('what s not enough for you to fill it up ?',
#   ' <str> <cc> 뭘 모자랴 다 채우니라구 그러구 잉 ? <end>'),
#  ('she s got the smoke and the splendor that only veterans can do .',
#   ' <str> <kw> 그녀에게는 베테랑만이 할 수 있는 연기력과 화려함이 있사 . <end>'),
#  ('how many houses do you think the east sea looks like ?',
#   ' <str> <kw> 야 동해 바다가 좌악 내려다 보이는 집이 대한민국에서 몇 채나 되겠나 ? <end>'),
#  ('my mom s just like my mom s and my mom s really bad just like your big father s .',
#   ' <str> <gs> 우리 엄마두 똑같애 우리 엄마도 엄청 유해졌어 너네 큰아버지 너네 아버지처럼 <end>'),
#  ('i m worried about you . i m worried about you .',
#   ' <str> <kw> 속이 깊어서 자네가 극정할까 봐 <end>'),
#  ('so it seems like its until i die',
#   ' <str> <jd> 긍까 죽을 때까지의 숙제인 것 같기도 해 . <end>'),
#  ('do you know how much this family messes up people s lives ?',
#   ' <str> <kw> 이 집안이 사램 인생을 얼매나 망치는지 아세요 ? <end>'),
#  ('who knows what s not a big deal ?',
#   ' <str> <kw> 쥐똥도아닌기 짜드니 누가 알아주나 ? <end>'),
#  ('he s a son of the distribution .', ' <str> <jj> 유통 아들로 나완 <end>'),
#  ('she said she s the only child in the middle . she said she s the only one who s gone .',
#   ' <str> <kw> 그렇잖아 애꿎게 얼라만 중간에 왔다리 갔다리 왔다 갔다 하고 . <end>'),
#  ('i thought if i was going to relax i d just be fine and i d do that and i d feel better .',
#   ' <str> <kw> 내 마음이 편할라면 그냥 잘 지내는 수밖에 없겠다 싶어 가지고 그렇게 했지 그렇게 하니까 난 마음이 편하더라고 <end>'),
#  ('well i didn t make any big distinctions with my grandmother but my brother had a lot of brothers .',
#   ' <str> <jd> 뭐 근데 그래도 크게 우리 할머니네 뭐 이르케 차별하지는 않았지만 그래도 오빠야 오빠를 많이 생겼었지 나는 근데 <end>'),
#  ('it s not like this .', ' <str> <kw> 이런 게 아니라 이름 이한테 즌화 한번 해봐 . <end>'),
#  ('i just want you to do something with your chest towards the mirror and i just want you to do something about it .',
#   ' <str> <jd> 쫌 막 먼저 뭔가 가슴이 거울 쪽으로 하고 가시게 하고 그냥 <end>'),
#  ('i mean you really didn t have any money to pay for the rent .',
#   ' <str> <kw> 진짜 달세 줄 돈도 없이 이래가 갔잖아 갔는데 <end>'),
#  ('i order it once a week', ' <str> <jj> 시키는디 뭐 일주일에 한 번 <end>'),
#  ('there s got to be there s got to be .',
#   ' <str> <jd> 이 시국에 어쩔 수 있것 있겄어 . <end>'),
#  ('at first i was feeling a little bit bad and thinking a little bit but i was talking to my friends about my personality .',
#   ' <str> <jd> 처음엔 뭔가 솔직히 쫌 기분 나쁘고 이렇게 쫌 생각하곤 했었는데 친구들이랑 얘기를 해봤었거든요 제 성격에 대해서 <end>'),
#  ('that s a little bit of a famous brand thing that we know about .',
#   ' <str> <gs> 흔히 우리가 알 만한 지금 쫌 유명한 브랜드의 그런 명품 그런 것도 나오고 <end>'),
#  ('that semi automatic machine came out so it was easy and if you can t just put it in there and do that then where am i ?',
#   ' <str> <jj> 그 반자동 기계도 나오고 하난 일이 쉬웠주 . 그냥 그 거기도 널고 경 허당 버치면 힘들면 저 어디냐 <end>'),
#  ('i don t want to see a watch .', ' <str> <jj> 시계 이시면 안보고 싶어도 <end>'),
#  ('what kind of person are you ?', ' <str> <kw> 당신은 우짼 사람이에요 ? <end>'),
#  ('i can t imagine being someone like that .',
#   ' <str> <kw> 그른 사램이라는 게증말 상상이 안가 <end>'),
#  ('smaller and smaller .', ' <str> <kw> 무를 좀더 쪼만히 썰어라 . <end>'),
#  ('sd and now i m looking back at the way that i ve graduated .',
#   ' <str> <jd> sd 그리고 이제 나도 졸어반 사람 입장에서 돌이켜 봤을 때 <end>'),
#  ('my land i m gonna build some land there and i m gonna do something about it .',
#   ' <str> <kw> 내 땅 내가 거다 농사도 좀 지어보고 뭐 해야지 . <end>'),
#  ('hey we used to go to school .', ' <str> <kw> 야 우리 예전에 핵교 다닐 때 <end>'),
#  ('i don t think it s real .', ' <str> <cc> 쫌 실감이 안 났던 거 같애 . <end>'),
#  ('if you try to eat you have to solve it but if he sits over there',
#   ' <str> <jj> 밥먹잰허믄 밥먹으려고 하면 막 풀어사 되는디 그사람이 저쪽에 앉앙이시믄게 <end>'),
#  ('the light went out . the fire went out . the cow went out .',
#   ' <str> <jj> 환허던불이 꺼지난 서울죙이는 시골죙이를 식당드레 <end>'),
#  ('i ll get you some dumplings student .', ' <str> <kw> 만도 줄까 학상 <end>'),
#  ('what if there s something wrong with you and your name ?',
#   ' <str> <kw> 그러다 당신 이름 이한테 무신 문제라도 생기면 어떡할라 그래 ? <end>'),
#  ('you re almost a year old lady aren t you ?',
#   ' <str> <jj> 거의 한 오십 대 아줌마 아니 ? 할머닌데 . <end>'),
#  ('its not that snowfall', ' <str> <jj> 눈이 경 막 뭍은 것도 아니라 . <end>'),
#  ('thats how it recurred and spread to the lymph nodes',
#   ' <str> <jj> 겅 핸 재발행 임파선까지 번졌댄 <end>'),
#  ('the land though said was important . laugh .',
#   ' <str> <jj> 토지만 토지는 중요하댄 해서 . 웃음 토지 . <end>'),
#  ('i don t know if there s a fire or smoke or something .',
#   ' <str> <jd> 그 불 빨아들이고 연기 빨아들이고 그런 거 있냐 하여튼 뭐 그런 건디 <end>'),
#  ('look at your face . you look like a gangster and you re running away .',
#   ' <str> <kw> 얼구리 봐라 깡패들두 보면 도망가게 생겼지 . <end>'),
#  ('do you think the women who lived with their father would have been so mean ?',
#   ' <str> <kw> 지 에비랑 살 때 새엄맙네 하는 예자들이 좀 구박을 했겠어 ? <end>'),
#  ('you get it all and eat it all', ' <str> <jj> 자기가 다 받고 자기가 다 먹어사 <end>'),
#  ('i ll call you .', ' <str> <kw> 즌화하께 . <end>'),
#  ('it s very complicated to keep changing his blood pressure again and again .',
#   ' <str> <kw> 계속 또 혈압약 바꾸는 것도 엄청 복잡하더라고 여기서 뭐 또 혈압약을 갖고 가 갖고 <end>'),
#  ('she s not okay .', ' <str> <kw> 어머이는 안 괜찮아 . <end>'),
#  ('i think i didnt feel that and grew up like this',
#   ' <str> <jd> 고 또 그런 것을 못 느끼고 이르케 자랐던 거 같애 . <end>'),
#  ('are you gonna keep saying this to yourself ?',
#   ' <str> <kw> 증말 동니 시끄럽게 자꼬 이럴거야 ? <end>'),
#  ('can you stop listening to music ?',
#   ' <str> <jj> 음악 듣다가 정지할 수 있는 거 ? <end>'),
#  ('sam leave your parents and your brother s friends .',
#   ' <str> <kw> 이름 씨 부모성제 친구 다 버리고 떠나서 <end>'),
#  ('i ve had a lot of insight over four and a half years of pure art .',
#   ' <str> <kw> 그게 아니라 제가 사년 반동안 순수 미술을 하미 하난 깨달음을 얻었어요 . <end>'),
#  ('i see all the students .', ' <str> <kw> 학상들 다 보거든요 . <end>'),
#  ('because im a little stubborn', ' <str> <jd> 왜냐면 나도 좀 막 은근히 고집도 쎄고 <end>'),
#  ('i d like to know if you ve ever met your husband and you ve had a big regret or something ?',
#   ' <str> <jd> 인쟈 남편분 만나시면서 혹시 아직까지는 크게 후회했던 경험라던지 그런 거 혹시 있으신지 그런 것도 궁금하거든요 ? <end>'),
#  ('i don t want that to come to you a little bit .',
#   ' <str> <kw> 그 말이 쫌 와전되지 않았으면 좋겠지만 <end>'),
#  ('you re talking to me . you re talking to me .',
#   ' <str> <kw> 그 다 나았다고 나와 가주구 막 유세하고 있잖아 <end>'),
#  ('what the hell is going on ?',
#   ' <str> <kw> 아니 지굼 무신 일인데 엄마가 저러시는 거야 어 ? <end>'),
#  ('now i know everything .', ' <str> <kw> 이제사 모든 걸 알겠네 . <end>'),
#  ('you look so far away .', ' <str> <kw> 하늘만침 멀리 보인다 . <end>'),
#  ('i m laughing at you but i m going to take off my computer .',
#   ' <str> <kw> 누우 마옴이 야시꾸리 한가부지 난 기양 웃는건데 나 지굼 컴퓨터 떼 갈게 <end>'),
#  ('it s the best thing to do .', ' <str> <kw> 아구는 찜이 제일 맛있다 . <end>'),
#  ('so i go and look at the hard rock and i see that it s about two and a half feet tall and it s so big it s so big .',
#   ' <str> <jd> 그래서 가서 이제 하성진을 보니까 키가 이 미터 삼십 센치인가 이러는데 엄청 커요 진짜 허벌라게 큰데 <end>'),
#  ('i m gonna tell you a couple of ways .',
#   ' <str> <jd> 좋을지 내가 몇 가지 방법을 얘기 할려고 혀 . <end>'),
#  ('a little bit more .', ' <str> <jd> 쫌 더 그게 받아 . <end>'),
#  ('you re gonna have to run out of water and you re gonna ride through it ?',
#   ' <str> <kw> 물이 출러덩 출렁해야는데 다 타니 배기능가 ? <end>'),
#  ('there s no such evil .', ' <str> <kw> 아주 악연도 이딴 악연이 없다 . <end>'),
#  ('you can turn around in the back of the gray forest and if you want to get some fresh air you re gonna have to get some fresh air .',
#   ' <str> <jd> 편백 숲 그쪽 돌아도 되는거고 바람 쐴라면 <end>'),
#  ('are you sure you re gonna do this in here ?',
#   ' <str> <kw> 저기 증말 여개서 할거야 ? <end>'),
#  ('yeah well i don t have a lot of graduate students .',
#   ' <str> <kw> 맞나 그거 때문이었나 아 뭐 학원생도 별로 없고 해가지고 <end>'),
#  ('it s just that it s not something i ve ever seen .',
#   ' <str> <cc> 그냥 그런 거는 내 눈에 들어오는 이케 <end>'),
#  ('i thought i should register and work harder',
#   ' <str> <jd> 등록을 하고 쫌 더 열심히 해 봐야겠다 생각을 했어요 근데 <end>'),
#  ('i wear a mask too much so my chin is now',
#   ' <str> <jj> 마스크 너무 껴가지고 이 지금 턱이 <end>'),
#  ('yesterday s lightning was great .', ' <str> <kw> 어재 번개는 대단했네요 . <end>'),
#  ('you saw a young woman . i m old right ?',
#   ' <str> <kw> 부장님 젊은 예자를 봤다고 아 고거 참 싱싱하네 하는 거 보면 나 늙은 거 맞죠 ? <end>'),
#  ('its like drying anchovies', ' <str> <jj> 꼭 메르치 말린 것 처럼 그렇게 돼 . <end>'),
#  ('it s all gone . you re the only one left .',
#   ' <str> <kw> 다 떠나고 니 하내기 남았다 . <end>'),
#  ('come over here and eat .', ' <str> <kw> 일루 와서 먹어 . <end>'),
#  ('you haven t arrived yet ?', ' <str> <kw> 너 안주 못도착했어 ? <end>'),
#  ('typhoon crushed all the oxygen .', ' <str> <kw> 태풍때문에 산소가 다 밍개졌어 . <end>'),
#  ('it reminds me of a lot of old times .',
#   ' <str> <jd> 그거 먹으면은 옛날 생각이 많이 나더라고 그런 거 보면 또 <end>'),
#  ('with a pair of heads my older sister s going to be married twice .',
#   ' <str> <kw> 머리 쌍가매 있으니 큰성이는 시집 두 번 가겄다 . <end>'),
#  ('so you were sick and admitted to the hospital ?',
#   ' <str> <kw> 그래서 너 병나고 벵원에 입원했던 거니 ? <end>'),
#  ('what do you have with nothing ?',
#   ' <str> <jj> 어디 무슨 빽이 있어 아무것도 없는 게 가진 게 뭐라 ? <end>'),
#  ('with my daughter at the time', ' <str> <jj> 딸이영 그때 같이 <end>'),
#  ('if it s like this if it s two kids like this it s going to hold it like this and it s going to look something like this on both sides of the equation .',
#   ' <str> <jd> 이게 글고 이게 애들 이릏게 두 명이 되면은 이릏게 서로 이릏게 잡아주고 이릏게 양쪽에서 이릏게 <end>'),
#  ('so the nurse of course made a mistake but she didn t want her baby to die .',
#   ' <str> <jd> 긍께 간호사도 물론 실수를 했는데 그렇다고 지 애기를 <end>'),
#  ('what kind of printer do you have ?',
#   ' <str> <kw> 당신은 우딴 종류의 프린터를 보유하고 계신가요 ? <end>'),
#  ('oh well i mean i don t even think i m supposed to be dieting but i don t think it s gonna work out like this .',
#   ' <str> <cc> 아 그러면 다이어트를 해야 되나라는 생각까지는 있지만 그게 이케 행동으로는 나오질 않는 거 같애 <end>'),
#  ('yes . welcome .', ' <str> <kw> 네 어푸 오세요 . <end>'),
#  ('she s got a lot of real english but she s dating again and that s where she s dating a foreigner .',
#   ' <str> <kw> 걔가 진짜 영어를 엄청 많이 늘어 가지고는 근데 걔는 또 연애를 했지 거서 외국인이랑 연애를 했지 . <end>'),
#  ('he s no good scholar .', ' <str> <kw> 그가 무신 훌륭한 학자리 . <end>'),
#  ('oh i know i dont usually do it like this',
#   ' <str> <jj> 아 그니까 나 원래 영 안 하는디 <end>'),
#  ('it s good to have a fight . it s good to have a fight .',
#   ' <str> <jj> 요기 싸우나가 좋네 저기 싸우나가 좋네 하면서이 <end>'),
#  ('i put maple leaves on the picture .',
#   ' <str> <kw> 사진에 단풍잎파구 붙이기도 하고 말야 . <end>'),
#  ('i tried to change your clothes and get out of here . what s going on ?',
#   ' <str> <kw> 네 옷만 갈아입고 금방 나가려고 했는데 무신 일 있으세요 ? <end>'),
#  ('you did it and then you did it .', ' <str> <jj> 겅 핸 ? 허난 겅 하당 <end>'),
#  ('the road s up .', ' <str> <kw> 기럭지 오르막이야 . <end>'),
#  ('i think i can .', ' <str> <jj> 될 수 있을 거 닮아 <end>'),
#  ('kupan does a lot of these things so i don t mean clothes so there s a lot of nice clothes .',
#   ' <str> <jj> 쿠팡 이런 것도 많이 하고 그니까 옷도 아니 그러니까 옷을 옷이 예쁜 게 너무 많네 <end>'),
#  ('i ve got somewhere to go .', ' <str> <kw> 나도 어데 가볼데가 있싸 . <end>'),
#  ('now for example whether you re a king or a prince or a son if you pass on a line like this you re a slave .',
#   ' <str> <gs> 예를 들면 이제 왕에 왕자든 아들이든 이르케 대를 물려가면 종 <end>'),
#  ('he s sucking . he s got another class teacher .',
#   ' <str> <jd> 빨가니깐 따른 반 쌤이 <end>'),
#  ('i was having a beer party .', ' <str> <jj> 맥주 파티 했어신디 <end>'),
#  ('i don t have much time left for work .',
#   ' <str> <kw> 퇴근 시간이 얼매 남지 않았어요 . <end>'),
#  ('i ve touched a cat and there s a rash .',
#   ' <str> <kw> 고양이를 만졌는데 두르레기가 나타나네 <end>'),
#  ('the reason is that you cant go every day so youre busy so youre doing other things',
#   ' <str> <jd> 왜그냐면 매일 못 가니까 바쁘니까 다른 일 하니라고 그러면 <end>'),
#  ('is there all that', ' <str> <jj> 뭐 그런 게 다인 ? <end>'),
#  ('so i m actually a public servant too .',
#   ' <str> <cc> 그면 저도 원래 사실 그 공무원 준비하시 시는 분들이 <end>'),
#  ('you re the one who experiences the bottom world that money can t buy right now .',
#   ' <str> <kw> 오빠는 지굼 돈으로 살 수 없는 개바닥 시상을 경험하는 주이야 . <end>'),
#  ('i don t want to be so vague .',
#   ' <str> <jd> 책임 전가가 뭐 아직까지도 이르케 불분명한 하자 하자나 <end>'),
#  ('they re working on traditional traditions .',
#   ' <str> <kw> 종래의 전통을 답습하고 있사 . <end>'),
#  ('well it s engineering anyway so there s this kind of thing .',
#   ' <str> <jj> 어쨌든 공학이니까 좀 이런 게 인네 . <end>'),
#  ('it felt a little like this .', ' <str> <jj> 약간 이런 느낌이연 <end>'),
#  ('get your balls out of the car in the back so you don t get stuck in the car .',
#   ' <str> <kw> 뒤의 차에 지장이 없도록 솔력을 내사 몰고 가라 . <end>'),
#  ('you said you weren t sick and you just said you weren t sick .',
#   ' <str> <jj> 안 아프다고 하고 막 이르케 <end>'),
#  ('i ve been married for over ten years .',
#   ' <str> <kw> 나 혼재 시집 십년 넘게 시직살이 했어요 . <end>'),
#  ('are you sure you re doing this ?', ' <str> <kw> 증말 양가 상견례라도 하는거야 ? <end>'),
#  ('i think you re right .', ' <str> <kw> 이녁 말이 옳은 것 같군요 . <end>'),
#  ('im trying to stirfry pendulum and stirfry fish cakes',
#   ' <str> <jd> 지짜 쪼끔이라도 막 하려 하거든 그리고 어묵 볶음 막 이런 거 하고 <end>'),
#  ('that s why she s so big and she s got a kid who lives in new york right now so i m like',
#   ' <str> <kw> 갸는 그래서 진짜 포부가 이래 커져 가지고는 지금 아예 그냥 뉴욕에 사는 애가 있거든 그니까 나도 <end>'),
#  ('don t waste it . don t waste it .', ' <str> <kw> 낭비하지 마고 저금하시오 . <end>'),
#  ('if i go somewhere i ll be alone .', ' <str> <jd> 내가 으디 나가고 가면 난리나 <end>'),
#  ('i did this a little bit .', ' <str> <jj> 이번 한해 어땠냐 약간 이런 식으로 핸 <end>'),
#  ('you ve been waiting a lot haven t you ?', ' <str> <kw> 마이 기다리셨죠 ? <end>'),
#  ('you ll believe me .', ' <str> <kw> 언니 니 믿을 거야 . <end>'),
#  ('then youll come out with four bags', ' <str> <jj> 그럼 네 봉다리 나오겠네 . <end>'),
#  ('what s your dad ?', ' <str> <kw> 아부지 뭐야 ? <end>'),
#  ('it s not a lawn that s planted like this it s plastic .',
#   ' <str> <cc> 거기는 이케 잔디가 이 심어져 있는 잔디가 아니라 플라스틱 <end>'),
#  ('he s in .', ' <str> <jj> 들어 간 <end>'),
#  ('what s wrong with your only daughter ?',
#   ' <str> <kw> 하내기밖에 없는 딸이 왜 그래요 ? <end>'),
#  ('why is she acting like a roommate in my house ?',
#   ' <str> <kw> 왜 우리집에서 자가 안방 마님 행세를 하고 있는거야 ? <end>'),
#  ('siaaban lived in the marriage', ' <str> <jj> 시아바님넨 시집오란 살암신디 <end>'),
#  ('oh yeah it s a lot of coffee so don t burden it on me .',
#   ' <str> <kw> 어 커 커피 많으니까 부담업씨 팍팍 넣으려구 팍팍 목청 <end>'),
#  ('aren t you a little timid of my sister ?',
#   ' <str> <kw> 내 동성 쫌 소심하지 않나 ? <end>'),
#  ('i m a little careful so i don t make a lot of mistakes .',
#   ' <str> <cc> 쫌 조심스러우니까 실수를 많이 안 해 성격이 ? <end>'),
#  ('you have to know what you re good at .',
#   ' <str> <kw> 당신 실력은 알아 조야 해 . <end>'),
#  ('in the days of play you ll be in the mountains you ll be in the woods you ll be in the sun .',
#   ' <str> <kw> 또 노는 날에는 산에 가 낭그해대야지 낭그 해와야 지 . <end>'),
#  ('how did she know in advance that i was going out ?',
#   ' <str> <kw> 어타 그녀가 내가 나갈 걸 미리 알 수 있었지 ? <end>'),
#  ('i think it s a little bit of a split .',
#   ' <str> <cc> 나누기에는 쫌 그런 거 같습니다 . <end>'),
#  ('i m so drunk that i can t just let him go .',
#   ' <str> <kw> 단속을 했는데 너머 취해서 도제 그냥 보낼 수가 없는 거예요 . <end>'),
#  ('you re saying you treated him for walking in his s ?',
#   ' <str> <jj> 구십사 년도에 그 워킹을 치료했다는 거잖아예 . <end>'),
#  ('we need to get up early tomorrow morning and get ready .',
#   ' <str> <kw> 내일 새복 일찍 일어나 준비해야겠네 . <end>'),
#  ('if you live here things are complicated .',
#   ' <str> <kw> 여개서 산다면 복잡한 일들이 있겠지만 . <end>'),
#  ('i saw him earlier and i miss him again .',
#   ' <str> <kw> 아깨 봤는데 또 보고 싶기도 하고 . <end>'),
#  ('yeah i think so . i cut her off and brought her back but she s got this little pot in my house .',
#   ' <str> <kw> 그러는 것 같애 엄마 좀 짤라서 그때 갖다줬었는데 우리 집 이 화분이 쪼끄만데 얘네가 <end>'),
#  ('take the puppy .', ' <str> <jj> 그 강생이 데령 <end>'),
#  ('it s also in essential subjects because it s important to have relationships with social people .',
#   ' <str> <jj> 대인관계 중요하다 해가지고 필수 과목에도 있언 . 사회인과 대인관계 해가지고 . <end>'),
#  ('i mean you should let your family in and if they say they re good in the world they ll love it .',
#   ' <str> <cc> 한마디로 집 식구들은 길을 들여놔야지 세상에 남의 것 맛있다고 하면 그 약 올라서 반찬 하겄어 ? <end>'),
#  ('and when you go to a place like seoul and you eat food like this',
#   ' <str> <jd> 또 서울 같은 데 가서 음식을 인자 이렇게 먹다 보면은 <end>'),
#  ('he s got a lot of steam on him .', ' <str> <kw> 증말 째증을 많이 내더라고 <end>'),
#  ('i m glad the weather s good .',
#   ' <str> <cc> 구월 달에 갈만 하드라고 날씨도 선선 선선하니 좋고 <end>'),
#  ('i think it s a little bit of a comfort too .',
#   ' <str> <jd> 어 그것도 진짜 쫌 편할 거 같아요 웃음 이제 들어보니까 <end>'),
#  ('i mean i said it but if you don t like it you don t have to say it .',
#   ' <str> <jd> 취지로 내가 말했는데 싫어하믄은 내가 말 할 필요가 없제 . <end>'),
#  ('it s a lot of times it s a little bit of a breezy thing .',
#   ' <str> <cc> 이게 브금 같은 게 좋아서 쫌 틀어두고 그러는 경우가 많단 말이야 . <end>'),
#  ('it s a little bit different here .', ' <str> <kw> 여개선 좀 그래 . <end>'),
#  ('please forgive me for thinking of my unborn child .',
#   ' <str> <kw> 뱃속의 아 생각해서 한 번만 용서해 주세요 . <end>'),
#  ('so i went there often but i didnt eat sashimi well and just went to eat meat',
#   ' <str> <jj> 그래서 자주 자주 갔었는데 회는 잘 안 먹고 그냥 고기 먹으러 간거 <end>'),
#  ('i couldnt do everything but my husband said he would serve me like that',
#   ' <str> <jj> 다 못해신디 남편이 겅 모신댄 허대 . <end>'),
#  ('he s lost more .', ' <str> <jj> 더 빠져부런이 <end>'),
#  ('you can just eat american soup at home .',
#   ' <str> <kw> 집 에서 그양 미역국 먹으문 돼요 . <end>'),
#  ('is it so wrong that i told you the whole story first ?',
#   ' <str> <kw> 제가 각서 얘기 먼저 한 게 그렇게 잔모 겁니까 ? <end>'),
#  ('it s not that someone can t live any longer it s that you re wrong .',
#   ' <str> <kw> 그건 누가 더 살고 못 살고가 아니라 누야가 잔모 산 기다 . <end>'),
#  ('that s what you passed that test too baby .',
#   ' <str> <jd> 그거 해경 그거 시험 합격한 거 그거도 있고 암튼 자기애 <end>'),
#  ('but lucky for you is wearing a ring .',
#   ' <str> <kw> 근데 다행히 이름 이는 반재를 끼고 있드라구 . <end>'),
#  ('i have a backache too .', ' <str> <kw> 나두 허리깽이 아프다 . <end>'),
#  ('it s called .', ' <str> <kw> 구만해 이름 야 . <end>'),
#  ('why did i want to eat it ? because of his friend s son .',
#   ' <str> <kw> 내가 먹고 싶어 먹었냐 웬수 놈의 친구 자슥 땜에 . <end>'),
#  ('i ve got a deal .', ' <str> <kw> 선약이 있사 . <end>'),
#  ('back then i was walking around a lot to see things .',
#   ' <str> <jj> 그때는 쫌 많이 걸어다년 이것저것 보러 . <end>'),
#  ('yeah well if you drink too much you can t get distracted .',
#   ' <str> <kw> 그래 술 너무 먹으문 정신 흐려져서 안돼 . <end>'),
#  ('theres a sangmu district over there and if theres any condition next to the city hall theres that place',
#   ' <str> <jd> 쩌기 상무지구 있는데 시청 옆에 거 만약 여건이 된다면 거기가 <end>'),
#  ('it s a little bit more intense if you take three steps to get a chancre .',
#   ' <str> <jd> 샹궈를 삼 단계로 먹으면 조금 더 매울 것이여 그것이 . <end>'),
#  ('should i buy some hair dye and put it in at home and the one i bought a henna in the past',
#   ' <str> <jd> 나도 지금 염색약을 좀 사서 집에서 들일까 글고 옛날에 이거 헤나 하나 샀던 사갖고 했던 거 <end>'),
#  ('that s life actually .', ' <str> <jd> 삶이 그러잖아 사실 . <end>'),
#  ('so come on fay i ll give you whatever you want .',
#   ' <str> <kw> 그래서 뭐 페이는 니가 원하는 대로 줄 테니까 오라 이런 식으로 얘기하는데 <end>'),
#  ('the two houses are the same size .', ' <str> <kw> 그 두 집으는 크기가 비슷해 . <end>'),
#  ('it s almost a year or two now and i used to eat it this morning when i was with my husband .',
#   ' <str> <cc> 지금 거의 뭐 일 년 이 년 돼서 나도 우리 신랑하고 있을 때 아침에 딱 어트게 먹었냐면 <end>'),
#  ('i think it s better not to break up like that .',
#   ' <str> <kw> 그케 망가지지 않는 게 나을 거 같다고 <end>'),
#  ('but there s so many of them and they re so good .',
#   ' <str> <cc> 근디 거기가 멸치가 그렇게 많이 나와 근디 멸치가 그렇게 좋아 . <end>'),
#  ('don t talk to me .', ' <str> <kw> 말두 마라 까딱했으면 <end>'),
#  ('you re having a good time this year .',
#   ' <str> <jj> 올해까지는 잘 열 놀 인 . 지금 <end>'),
#  ('where are you going ?', ' <str> <kw> 근데 어데 다녀와 ? <end>'),
#  ('so insurance is the best thing to do .',
#   ' <str> <kw> 흐흐흐 그래이 보험은 마이 들어놀수록 좋은기야 . <end>'),
#  ('she said she didn t have any family .',
#   ' <str> <kw> 그 예나 식구도 아무두 없다며 . <end>'),
#  ('so it s not funny .', ' <str> <kw> 그래서 재미가 움사 . <end>'),
#  ('the weatherman predicted that tonight s snow would come .',
#   ' <str> <kw> 관상대원은 오눌 밤눈이 올 거라고 예보하더군요 . <end>'),
#  ('so what are you doing these days ?', ' <str> <kw> 그럼 요새간에는 뭐 해요 ? <end>'),
#  ('only when unification is reached should we disperse it',
#   ' <str> <jj> 통일돼야만이 이제 분산시켜갖고 <end>'),
#  ('you said you d say hello to someone who was going to be your wife s wife .',
#   ' <str> <kw> 참 형수 될 분 집에까지 인사 왔었다메 ? <end>'),
#  ('this fish can eat every last bone .',
#   ' <str> <kw> 이 생선은 뼈째 몽조리 먹을 수 있어 . <end>'),
#  ('she can t touch it .', ' <str> <kw> 살무새는 만지면 안 돼 . <end>'),
#  ('you go on the first day eat two meals eat the next morning have lunch have dinner come on do this .',
#   ' <str> <jd> 가서 첫날 가서 두 끼 먹고 다음날 아침 먹고 점심 먹고 저녁 먹고 온다 이르케 해도 <end>'),
#  ('it s my heart . why ?', ' <str> <kw> 내 맘이야 왜서 . <end>'),
#  ('i m going to have a homepage and i m going to set it up .',
#   ' <str> <cc> 홈페이지 가 갖고 그거를 설정을 해 갖구유 <end>'),
#  ('so anyway dont be confident in health and health and always eat well and eat well not special food',
#   ' <str> <jj> 경허난 어쨌든 우리가 건강 건강 자신하지말고 예 늘 잘 먹고 뭐 먹는 음식 특별한 음식 말고 그냥 잘 먹고 예 <end>'),
#  ('it s okay . it s okay .', ' <str> <jj> 크멍 말멍 <end>'),
#  ('my brother is not a nurse he s a nurse he s not a nurse he s a nurse he s not a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s not a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s not a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s not a nurse he s a nurse he s a nurse he s a nurse he s not a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse he s a nurse .',
#   ' <str> <gs> 제 동생이 아 간호사 말고 충분히 따른 길을 한 번 찾아보고 <end>'),
#  ('no lets do that instead of that lets tell me what that parttime job is',
#   ' <str> <jj> 아니 그거 말고 이 겅하게 . 그 젤 기억 남는 아르바이트 뭔지 말해보게 . <end>'),
#  ('no matter what .', ' <str> <jj> 아멩 <end>'),
#  ('you can talk to the town office call the city hall talk to them .',
#   ' <str> <jj> 읍사무소 얘기하고 시청에 전화 행 얘기하고 해도 <end>'),
#  ('so the stones are very', ' <str> <jj> 겐 돌멩이들 막 <end>'),
#  ('what do you have to say is that you re a parent s child ?',
#   ' <str> <kw> 부모 자석이라구 할 거 있어요 ? <end>'),
#  ('my brother s going to pay off your sister s debt and let her die to collect million .',
#   ' <str> <kw> 우리 형 니 어니 빚 갚으러 다녀 삼억 사천을 모으겠다고 일을 죽도록 한다고 . <end>'),
#  ('it s an agricultural water source and it s a little bit high and it s deep .',
#   ' <str> <jd> 농수로 농사짓는 그 물을 대는 농수로인데 쫌 높아요 깊어요 . <end>'),
#  ('they say stock is a risk asset .',
#   ' <str> <jd> 주식은 위험자산이라고도 많이 얘기하는디 <end>'),
#  ('there s also a sense of excitement about the sad winter scene .',
#   ' <str> <kw> 앙상한 저울 경치에도 또한 정취가 있사 . <end>'),
#  ('i m so sorry for you .', ' <str> <kw> 어 앉아 봐 자네한테 너머 미안하네 . <end>'),
#  ('i ve heard that before .', ' <str> <kw> 예즌에는 들였어 . <end>'),
#  ('and of course as promised we re gonna do a lot of cross reports .',
#   ' <str> <kw> 물론 약속대로 상호명홍보도 충부이 할거고 . <end>'),
#  ('isnt it better than discharge no', ' <str> <jj> 제대 보단 낫지 않 ? 아니 <end>'),
#  ('i ll see you in a minute .', ' <str> <kw> 금 있다 뵐게요 . <end>'),
#  ('if you go to a replacement and rewind it you ll have to borrow your own room and go back and forth .',
#   ' <str> <jj> 대치동 강 재수 시키민 이녁이 방 이제 빌고 왔다갔다 해야된다는 거라 . <end>'),
#  ('i just got off the gym for a discount and i was just about a month away .',
#   ' <str> <jd> 할인된 거 막 사고 막 헬스장 끊었는데 막 한 달밖에 안 가고 막 그랬었는디 <end>'),
#  ('and i m gonna buy a park cemetery somewhere close to where i can go every day .',
#   ' <str> <kw> 그래구 내가 날마다 가 볼 수 있는 가까운 데 공원묘지 사 놓고 <end>'),
#  ('and that s the game that they re looking for .',
#   ' <str> <jd> 그러면 그 동료들이 그 임포스터를 찾아내는 게임인디 <end>'),
#  ('it s all about the old fashioned home mom and go to go go go go go go back .',
#   ' <str> <kw> 그기 다 옛날 그 고향 엄마 그 생각나는 거지 . <end>'),
#  ('let s do that .', ' <str> <jj> 겅해부난 . <end>'),
#  ('but then i asked him to marry me because my friend didn t want me to marry him because i wasn t prepared and because of that guy s drink .',
#   ' <str> <cc> 근데 결혼을 하자고 했지 친구가 나는 결혼할 생각이 없었거든 준비도 안되어 있고 그 친구의 그 술 때문에 <end>'),
#  ('really if you do a festival or something like that',
#   ' <str> <jj> 진짜 이 축제 같은 거 해도 이 <end>'),
#  ('i now have my own custom of being a virgin .',
#   ' <str> <jd> 나는 인자 내 나름대로 처녀 때부터 했던 그 습관이 있으니까 <end>'),
#  ('i khow should i ask', ' <str> <jj> 그니까 물어봐사켜 <end>'),
#  ('in the evening i think i work with a child who works in the evening if theres anyone who will be with me i can go in the evening',
#   ' <str> <jj> 저녁에 저녁에 나는 이 직장 다니는 아이도 같이 다니는지 막 이 같이 다닐 사람 있으면 저녁에 가도 되거든 . <end>'),
#  ('i live for you .', ' <str> <kw> 아유 내가 당신 때미에 살아요 증말 . <end>'),
#  ('don t worry about it . you re on your way .',
#   ' <str> <kw> 신경 쓰지 말고 너 갈 질이나 가 . <end>'),
#  ('this is how it works .', ' <str> <jj> 영 된다니까 <end>'),
#  ('i went on a trip to vietnam my oldest sister and they say it s very difficult .',
#   ' <str> <kw> 우리 큰누우가 베트남여행을 갔는데 그곳은 스콜가 심하다고 한다 . <end>'),
#  ('you didn t think about it until you got married did you ?',
#   ' <str> <kw> 게론까진 생각해 보지 않았는데요 ? <end>'),
#  ('but i don t think you re following me right now so i can t tell you that you re not following me .',
#   ' <str> <jd> 근데 뭐 니가 지금 잘 따라오니까 솔직히 말해서 못 따라온다고 생각 안해 . <end>'),
#  ('i have to give up a little bit of the world .',
#   ' <str> <jd> 쫌 세상적인 걸 포기해야 되는 데 나는 또 <end>'),
#  ('if you don t let it go it ll be a thousand like you .',
#   ' <str> <jd> 그렇게 놔두면 안 내면 자기처럼 몇 천 돼브니까 <end>'),
#  ('thats why apple music is meaningless',
#   ' <str> <jj> 그래서 애플뮤직이 의미가 없는 거 . <end>'),
#  ('why don t we at least do everything we did in this book right now ?',
#   ' <str> <kw> 그럼 최소한 이 책에서 한 거는 빨라당 다 해봐야 되지 않을까 ? <end>'),
#  ('but now people uh high blood pressure and all this stuff it s a blood vessel problem .',
#   ' <str> <jd> 근데 인제 사람이 인제 어 이런 고혈압이나 그런 것도 다 혈관 문제잖아 <end>'),
#  ('that student graduated early . i envy you .',
#   ' <str> <kw> 저 학생은 조기졸업을 했어 부러봐 . <end>'),
#  ('even if my dad cant live with me he will get an award at my family',
#   ' <str> <jj> 우리 아방이 난 우리 모션 살지는 못해도 우리집이 상 <end>'),
#  ('i m not answering my phone .', ' <str> <kw> 집에 즌화 안받는다구 저더러 <end>'),
#  ('how do you order it ?', ' <str> <kw> 어떠 주문합니까 ? <end>'),
#  ('that money costs only thirty four years .',
#   ' <str> <jd> 해년마다 되도록이믄 해 봐 그 돈 그거 해 봤자 삼사십밖에 안 들잖아 . <end>'),
#  ('have you ever played a drop of water ?', ' <str> <kw> 비눌놀이 해봤어 ? <end>'),
#  ('what s the matter with you ?', ' <str> <kw> 뭘 얼매나 고상을 해서 이래 ? <end>'),
#  ('i m sorry i kissed you .', ' <str> <kw> 키스한거 잘모했다구요 . <end>'),
#  ('i don t have any friends .', ' <str> <jj> 벗 어서 비대면 거의 된덴 해부난 <end>'),
#  ('you two have a lot of fun . bring your friends .',
#   ' <str> <jd> 둘이 얼마나 즐기는가 많이 친구들을 데꼬 오지 . <end>'),
#  ('but now my son is saying that', ' <str> <jd> 그러드라고요 근데 이제 아들이 아 가지구 <end>'),
#  ('that s why i m so fat .', ' <str> <jd> 그렇게 살이 쪄브리니까 이게 <end>'),
#  ('i want to go over there .', ' <str> <jj> 아 거기 가보고 싶 협재식물원 <end>'),
#  ('i ve done it pretty much all the way around .',
#   ' <str> <jj> 그 주변에도 잘도 예쁘게 어쨌든 해놨어 <end>'),
#  ('that s not the point .', ' <str> <kw> 그른 건 중요한 거 아냐 . <end>'),
#  ('if the number of people who show his wealth is higher he will show his wealth .',
#   ' <str> <kw> 그 사람의 가장 부를 나타낸 것 층수가 높으면 그거의 부를 나타낸다 그러드라고 그래서 <end>'),
#  ('oh i was greedy again i said do i have to buy more or more i think its going up a little bit i have to buy more',
#   ' <str> <jd> 아 또 욕심이 나는거야 마 아 더 사 더 사해야 되나 아 좀 오르는 것 같애 더사야되나 이랬는데 <end>'),
#  ('four guys in shorts one leg one leg one leg one leg one leg one leg one leg one leg .',
#   ' <str> <jj> 반바지를 입었는네 개가 한 쪽 다리만 완전 매끈하고 한쪽 다리는 털이 완전 덥수룩한 거라 웃음 <end>'),
#  ('why don t you cry for something like that ?',
#   ' <str> <kw> 자석이 뭐 그른 일에 울구 그래 . <end>'),
#  ('he ran away with his daughter ?', ' <str> <kw> 가가 그 집 딸을 꿰차고 날랐다고 ? <end>'),
#  ('where did you go to school ?', ' <str> <kw> 어는 학교를 다녔습니까 ? <end>'),
#  ('yeah well the first thing i saw with that was probably naruto .',
#   ' <str> <jd> 그 그래 가지고 맨 처음 본 것이 아마 나루토였을 겨 . <end>'),
#  ('yeah well i had him do it online this time .',
#   ' <str> <cc> 단종되었더라고 그래 가주구 나는 이번에 온라인으로따가 시켰는디 <end>'),
#  ('i m sitting there without my dad knowing it and when people live they don t have anything to do with it but i don t know what to do with it .',
#   ' <str> <kw> 아빠가 모르진 앉는데 사램이 살다보면 두루 준비두 못했는데 덜컥 일이 생기구 그러기두 한다 . <end>'),
#  ('if you stop it and go on this statue there are many mobs',
#   ' <str> <jj> 그걸 못허게 해 나보고 이 동상 위에 가면 폭도들 있고 <end>'),
#  ('we have to turn around .', ' <str> <kw> 발길을 돌릴 수밖에 읊어 . <end>'),
#  ('can you explain why we need to invest so much extra ?',
#   ' <str> <kw> 왜 우리가 그닷하게 추가 투자할 필요가 있는 지 그 이유를 설명해 줄 수 있습니까 ? <end>'),
#  ('why do you have me now grandma ?',
#   ' <str> <kw> 왜 요즘 날 가지고만 그러는데 할머이 ? <end>'),
#  ('he was famous for your school .',
#   ' <str> <kw> 야자랑 어 야자랑 그 보충 그런 거 냬 너네 학교 되게 유명 했어 . <end>'),
#  ('my father killed three people .',
#   ' <str> <kw> 아버지가 사램을 셋이나 죽인 살인범이고 <end>'),
#  ('i don t know what you re talking about and i don t know what you re talking about .',
#   ' <str> <kw> 이름 야 용즘 엄마 힘들다 이런 얘기도 가인데 나도 모르게 하게 되는 거고 <end>'),
#  ('i m kim . he s probably from the mine .',
#   ' <str> <jj> 나 김씨야 걔도 광산 김씨 일거라 . <end>'),
#  ('that s why my brother and sister are the only ones who raised me now .',
#   ' <str> <cc> 그러면 남매만 인자 키운 거지 그랬는데 <end>'),
#  ('i thought it tasted a little bit good in the military .',
#   ' <str> <jd> 의외로 군대에서 운동에 쫌 맛이 들렸었거든요 . <end>'),
#  ('there s no maple in the area .', ' <str> <kw> 가근방부터 단풍이 졌어 . <end>'),
#  ('that s why i m so grateful .',
#   ' <str> <kw> 그래서 하두 고마워서 이렇게라두 좀 해본거유 . <end>'),
#  ('i was at dogad s house and then i was filled with a dogad s house .',
#   ' <str> <jj> 도겟집에서 그때 도겟집 하나 꼬뜩 해났주게게 <end>'),
#  ('so there must have been a rumor in a good school .',
#   ' <str> <jd> 그니까 공부 잘하는 학교 내에서 소문이 났나 봐요 . <end>'),
#  ('no thats out if you go up to or youll love it',
#   ' <str> <jj> 아니 그 거는 나와서게 서른 서른 둘까지 허믄 말주 <end>'),
#  ('yeah youre nice one on your side', ' <str> <jj> 기이 ? 착허다 이 <end>'),
#  ('there s a nurse s assistant when she goes to the p . a . and registers there .',
#   ' <str> <jd> 쩌기 목포에 가믄 간호보조학원이 있대 거기 가서 등록해서 <end>'),
#  ('but i broke up with him .', ' <str> <kw> 근데 지가 헤어지자고 했어요 . <end>'),
#  ('but i do too . i don t know . i don t know . i don t know . i don t know . i don t know . i don t know .',
#   ' <str> <jd> 근데 나도 그래 남들은 뭐 절임 김치 사고 뭐 그 기냥 만들어진 김치 사고 <end>'),
#  ('i ve been called more just because you re eating .',
#   ' <str> <kw> 형도 먹는다고 해서 더 뿔궈 놨어요 . <end>'),
#  ('how s it going brother ?', ' <str> <kw> 싱야님 잘해주시디 ? <end>'),
#  ('im so busy these days to get along with each cousin so its a contact date',
#   ' <str> <jd> 각 사촌들하고도 친하게 지낼려면 요즘 하도 바쁘고 그러니까 연락일 <end>'),
#  ('we haven t lost love but have you ever thought about how she must feel ?',
#   ' <str> <kw> 우리가 사랑이 식어 헤어진 게 아닌데 그 예자가 어뜬 심정일지 생각해 보셨냐구요 . <end>'),
#  ('do something nice and fancy between the two .',
#   ' <str> <kw> 양단간에 뭔가 뽀대 나고 멋있는 일을 좀 해보세요 . <end>'),
#  ('it s good to have them all cleaned up and saved them and didn t have to eat them .',
#   ' <str> <cc> 이렇게 손질을 싹 해가지고는 저장 해놨다가 꼭 못 먹고 하면은 좋겠드라고요 . <end>'),
#  ('i don t know how this happened to my house .',
#   ' <str> <kw> 어쩌다가 어쩌다가 우리 집이 이렇게 됐는지 난 상구 <end>'),
#  ('and you re looking at the line ?', ' <str> <kw> 그래구 선을 볼 겁니까 ? <end>'),
#  ('so how scary would it be for the listeners and other people',
#   ' <str> <jj> 겅허난 말이 그러니까 듣는 사람들 그 타지 사람들은 얼마나 또 무서울거꽈 ? <end>'),
#  ('i ll go with your mother and you ll have with your mother .',
#   ' <str> <kw> 나는 네 엄마랑 같이 갈 테이까 너는 이름 이랑 그짝 어머니랑 모시고 딸로 와 . <end>'),
#  ('the atmosphere is right now', ' <str> <jj> 지금 분위기가 딱 잡현 . <end>'),
#  ('we need to get the course right .', ' <str> <jd> 코스를 잘 잡아야 된대니까 . <end>'),
#  ('or forcing it to read it but forcing it to do it',
#   ' <str> <jd> 아니면은 막 읽을려고 막 억지로 억지로는 좀 그런데 어 이케 <end>'),
#  ('so it s a little bit like college it s fashion it s a little bit of child training .',
#   ' <str> <gs> 까 약간 좀 대학처럼 패션과도 있고 유아 교육도 있고 <end>'),
#  ('i m looking for a job but there s still no place for it .',
#   ' <str> <kw> 일자리 알아보긴 하는데 마땅한 짜리가 상가 안 나타나네 . <end>'),
#  ('uh so i didn t go to school i made some money i just . . .',
#   ' <str> <jj> 어 경행 안가그넹 휴학하고 돈 벌어그넹 그냥 <end>'),
#  ('he s gonna have one of his babies and he s gonna love him .',
#   ' <str> <kw> 애가 지 애기를 하내기 남펜 사랑을 받기를 하나 . <end>'),
#  ('what the hell is that ?',
#   ' <str> <kw> 또 뭐야 그 내 수술했는 그게 뭐야 이거 이거 어 목에 <end>'),
#  ('small things so', ' <str> <jd> 짜실한 것들 그니까 <end>'),
#  ('what am i old boy ?', ' <str> <kw> 내가 뭐 올드 보이나 ? <end>'),
#  ('i thought i wanted to meet you after i looked at your picture .',
#   ' <str> <kw> 네 사진 보더니 만났으문 하는 거 같다고 최 선생이 그러던데 ? <end>'),
#  ('let s check this out first .', ' <str> <kw> 이런 거를 먼전 확인을 하고 <end>'),
#  ('you need to get a good night s sleep from now on .',
#   ' <str> <kw> 오놀부턴 잠도 푹 자고 그래야 해 . <end>'),
#  ('sometimes they just yell at us for being loud and sometimes they just . . .',
#   ' <str> <jd> 어쩔 때는 우리한테 걍 시끄럽다고 욕을 할 때도 있고 어쩔 때는 이제 막 <end>'),
#  ('we re gonna have to eat it so we re gonna have to line it up .',
#   ' <str> <jj> 일단 먹긴 먹어야겠으니까 줄서게 해 가지고 <end>'),
#  ('he told me he was going back to the dust because he came from the dirt .',
#   ' <str> <jd> 흙에서 왔기 때문에 다시 흙으로 간다고 해서 돌아가셨다고 글드만 . <end>'),
#  ('what s the matter with you ? what s wrong with you ?',
#   ' <str> <kw> 미련곰탱이 이름아부지 증말 야자 문젠 속 안썩였니 ? <end>'),
#  ('is that what you re saying in this situation ?',
#   ' <str> <kw> 넌 이런 상황에서 그른 말이 나오니 ? <end>'),
#  ('women usually cry .', ' <str> <kw> 대개 여재들 우는 거 가지구 . <end>'),
#  ('does it make sense that it s just the reason for marriage that you re comfortable ?',
#   ' <str> <kw> 단지 편한 게 겨론의 이유라는 게 말이 돼 ? <end>'),
#  ('it s not like we re going out there a lot so yeah .',
#   ' <str> <cc> 밖에를 밖에를 많이 안 나가는 추세라서 예 쫌 <end>'),
#  ('next year it s a year and a year and it s a year and a year and a year and a year .',
#   ' <str> <kw> 내현이면 이름졸업인데 . <end>'),
#  ('who s responsible ?', ' <str> <kw> 누거 책임을 질런고 ? <end>'),
#  ('the neckline s just this nice round too . it s a little up and running .',
#   ' <str> <cc> 목선이 그냥 이르케 라운드 이것도 좋은 게 라운드 같은데 약간 올라오고 도톰해서 <end>'),
#  ('the end of the branch spreads out .', ' <str> <kw> 가젱이 끝이 뻗어나가다 . <end>'),
#  ('i ve been sitting here all night .',
#   ' <str> <kw> 그것도 대관령 서낭당에 와서 이래 쉬고 앉았는데 <end>'),
#  ('no it s not .', ' <str> <gs> 아인데 <end>'),
#  ('the world .', ' <str> <kw> 시상이 <end>'),
#  ('the story almost ended with a happy ending .',
#   ' <str> <kw> 그 이야기는 거진 행복한 결말로 끝났어 . <end>'),
#  ('dad came to yoonmi s house ?', ' <str> <kw> 아부지가 윤미 집에 왔다구 ? <end>'),
#  ('it s just you and me with your name on it .',
#   ' <str> <jj> 이름만 올령 나둘 뿐 <end>'),
#  ('i can t even get a little bit of it out of there .',
#   ' <str> <kw> 거게서 쬐금도 더가 안돼 <end>'),
#  ('i have a song for you to think about and i ve heard it a little bit since i was .',
#   ' <str> <jd> 널 생각해라는 노래가 있어 그 노래도 내가 스무 살 때부터 쫌 많이 들었어서 많이 기억에 남고 <end>'),
#  ('it s going to take a long time to change .',
#   ' <str> <kw> 변하는 시간이 질래 걸릴꺼아냐 . <end>'),
#  ('let s see what s going on .', ' <str> <kw> 실물이나 빨라당 보여줘 . <end>'),
#  ('my assistant taught me that five week car .',
#   ' <str> <jj> 미쳤지 ? 조교가 수업핸 그 오 주 차를 <end>'),
#  ('i feel a lot and i don t know if i m going to work anymore so we re just gonna keep going on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and on and',
#   ' <str> <jd> 많이 느끼고 그리고 내가 인제 일을 안 하면 모를까 계속 우리는 언니도 그렇지만은 <end>'),
#  ('in a way its like youre not going to buy it and youre going to buy it',
#   ' <str> <jd> 어떻게 보면 사도 않을 검시롱 살 것처럼 하면서 <end>'),
#  ('when we were in threedy how did they come out over there the place where we lead by the ship is over there',
#   ' <str> <jd> 그런 쪽은 우리가 여기서 쓰리디 있을 때 저기는 어뜨케 나왔대 배로 앞서가는 데가 저쪽이야 <end>'),
#  ('you know there were some english speaking kids back then and then there were some other things and then there were some go and go go to go to go to go to go to go to go .',
#   ' <str> <jd> 막 그때 영어 영어 했던 애들도 있고 뭐 따른 거 뭐 바둑이나 뭐 이런 거 <end>'),
#  ('i mean how did you get the spanking first of all get up on your desk get on your knees and see the soles of your feet ?',
#   ' <str> <jd> 그 어떻게 매를 드셨냐면은 그 우선은 책상 위로 올라가라그려 올라가라 그래 해서 무릎 꿇고 그럼 발바닥이 보이자녀 <end>'),
#  ('i like the country i used to live in .', ' <str> <kw> 마음에 그래구 있던 고국 <end>'),
#  ('i m looking for something different something different nothing different .',
#   ' <str> <jj> 색다른 것만 찾는다 색다른 거 뭐 색다른 거 어샤 뭐 색다른 거 어샤 <end>'),
#  ('whatever if i was hit by a car', ' <str> <jj> 뭐 차에 치여신지 어째신지 <end>'),
#  ('it s just that in a book written by mr . laws',
#   ' <str> <jj> 어 법률스님 법률 스님이 쓴 책 중에 그런거 막 이 이북으로 보면서 마음이 <end>'),
#  ('good job here and there .', ' <str> <jj> 여기저기 잘했어 이름 아늘 어떵 나올 거 <end>'),
#  ('so she sent all her pictures to her grandmother s house .',
#   ' <str> <kw> 그래서 엄마 사진 있던 거 다 외할머이 집에 보냈데요 . <end>'),
#  ('it wasn t just him . it was his name mom .',
#   ' <str> <kw> 기양 그 자린 첨부터 자신이 아닌 이름엄마 짜리였다고 <end>'),
#  ('a little bit .', ' <str> <jj> 쫌 그랬지 . <end>'),
#  ('don t think too much . he doesn t like to think too much .',
#   ' <str> <kw> 생각 마이 하지마 생각 마이 하는 거 벨로 안 좋대 . <end>'),
#  ('now go . take it . you don t even have a room .',
#   ' <str> <kw> 인재 갔어 가 가지고는 방도 하나 안 얻어 놨으니 <end>'),
#  ('what s my friend asking me to do now ?',
#   ' <str> <jj> 친정에서 이 천 만원인가를 이제 뭐 하라고 준댄 ? <end>'),
#  ('uh i didnt know marvel movies when i was in high school so i didnt know avengers one',
#   ' <str> <jd> 어 나 마블 영화를 고등학교 이 학년 때 근까 어벤져스 원은 몰랐고 <end>'),
#  ('if you re lucky it s samsan .', ' <str> <kw> 우째다 운 좋으문 신령초나 캘까 <end>'),
#  ('thats why i was surprised when i saw it in person because of rm and jhope',
#   ' <str> <jd> 그래서 그런 거지 이게 실물 보고 다 놀랜 게 알엠하고 제이홉 <end>'),
#  ('we don t know how to do it .',
#   ' <str> <jj> 안심코드 설치 허랜 햄수다 . 우린 헐주 몰라부난 <end>'),
#  ('i told him i couldn t do it . i told him i couldn t live without you .',
#   ' <str> <kw> 난 안된다고 못 한다고 그랬더니 당신 나 없으믄 못 산다고 <end>'),
#  ('it must have been hard .', ' <str> <kw> 마이 힘들었겠다 . <end>'),
#  ('the little girl in the house is beautiful .',
#   ' <str> <kw> 저 집 언내는 예쁘다 . <end>'),
#  ('well i mean living that way . . .', ' <str> <jd> 음 그니깐 그렇게 사는 건 <end>'),
#  ('i don t know but i need your help because i m having a hard time .',
# ...
#  ('if you turn it off it s a giant .', ' <str> <kw> 끄트마리면 거제도 . <end>'),
#  ('thats true but these days here', ' <str> <jj> 겅 헌디 이디는 요새 <end>'),
#  ('i want to marry someone who is more trusted than i am .',
#   ' <str> <jj> 나도 나보다 믿음 좋은 사람이랑 결혼하고 싶은디 <end>'),
#  ('i don t think it s gonna be easy .', ' <str> <jj> 힘들긴 할 거 닮아 <end>'),
#  ('if you do that you ll see your brother in law .',
#   ' <str> <kw> 그 일 하게 되면 아이씨 처남도 보게 될 거 아냐 . <end>'),
#  ('when i went to the station the train was already on its way .',
#   ' <str> <kw> 내가 정거장에 갔을 때 기차는 하마 출발했었어 . <end>'),
#  ('something s wrong with me a little bit .',
#   ' <str> <kw> 뭔가 나는 쫌 그래 . <end>'),
#  ('save your clothes .', ' <str> <kw> 옷을 애끼 입는다 . <end>'),
#  ('i think i ve eaten a lot of this same kind of soda .',
#   ' <str> <kw> 요런 종류의 음료수를 마이 먹은 거 같애 . <end>'),
#  ('i ve got the smell of nauseous tigress and my throat .',
#   ' <str> <kw> 시큼한 귀신손 냄새에 목이 메었어 . <end>'),
#  ('that s how you feel because there are a few people who have jobs that you can go to for the rest of your life .',
#   ' <str> <cc> 평생 갈 수 있는 직장을 가진 사람들이 몇 명이나 있다 보니까 그렇게 너가 느끼는 거라니까 근까 너는 그냥 <end>'),
#  ('i m the one who doesn t want to be the same as everyone else okay ?',
#   ' <str> <kw> 나는 다른 사램들하고 똑같은 건 무조끈 하기 싫은 사람이예요 . 아시겠어요 ? <end>'),
#  ('come on let s order . there s a lot of people out late .',
#   ' <str> <kw> 어서들 주문 하자 사램 많아서 늦게 나와 . <end>'),
#  ('i ll leave you alone . i can t say anything i can t say later .',
#   ' <str> <kw> 가만 내버려 두니까 내중에는 못 할 말이 없구나 ! <end>'),
#  ('did you surprise my dear sister ?',
#   ' <str> <kw> 사랑하는 내 동상 놀랬어 놀랬나 ? <end>'),
#  ('what s that all of a sudden ?', ' <str> <kw> 갑자키 그게 무신 ? <end>'),
#  ('so i put it in and the first month was free .',
#   ' <str> <cc> 그래서 그러면 그걸 가입을 했어 그랬더니 제일 처음 한 달은 무료드라고 <end>'),
#  ('i m just gonna go over there and take out a piece of rice from my mom .',
#   ' <str> <kw> 단지에 가서 먼 짐치를 한 바가지 꺼내와야지 뭐 우리 어머이가 <end>'),
#  ('but now i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going back to school and i m going to go back to school and i m going back to school and i m going back to school and i m going to go to school and i m going back to school and i m going to school .',
#   ' <str> <jd> 이 고민도 겁나 하게 되대 어 그래도 이제 학교 복학하 군대 갔다 와서 <end>'),
#  ('you re feeling so good you re completely you re you re feeling so good so i m going to talk to the groom about it .',
#   ' <str> <jd> 너무 기분이 좋은 거예요 오늘 컨디션 완전히 진 진짜 기분이 좋은거에요 그래가꼬 내가 인제 신랑한테 여보 <end>'),
#  ('his face is ugly .', ' <str> <kw> 얼구리가 까칠하다 . <end>'),
#  ('that sentence doesn t make sense without looking at the context .',
#   ' <str> <kw> 그 문장은 전후 관계를 보지 않고는 이해할 수 음싸 . <end>'),
#  ('that s the way i was before .',
#   ' <str> <kw> 그전에야 그렇게 찍어대구 놀러 가구 했지 . <end>'),
#  ('left for lunch . did you call him ?',
#   ' <str> <kw> 이름 이 점슴 먹으러 나갔는데 즌화 안 해보셨어요 ? <end>'),
#  ('that s what he said .', ' <str> <jj> 거기가 그렇댄 핸 . <end>'),
#  ('that s right . if you lose more you ll be patient and explode .',
#   ' <str> <kw> 맞아 더 많이 쭐이면은 참다가 폭발하거든 . <end>'),
#  ('the weather is good in the spring .', ' <str> <kw> 봄이 왔이니 날씨가 좋아 . <end>'),
#  ('hey you re . . .', ' <str> <kw> 야 근데 니는 <end>'),
#  ('that shirt doesn t fit me .', ' <str> <kw> 그 셔츠는 나떠러 맞지 않아 . <end>'),
#  ('so don t act like my mother s daughter in the future .',
#   ' <str> <kw> 그래니까 앞으론 우리 엄마 딸이나 되는 듯이 행동하지 말아요 . <end>'),
#  ('is the door open ?', ' <str> <jj> 문 열어수가 ? <end>'),
#  ('yeah i don t think that s a good idea .',
#   ' <str> <jd> 그래가지구 나는 그런 거는 쫌 안 좋은 거 같긴 한데 <end>'),
#  ('yeah kim young min s going to use the standard form for a modern day transition .',
#   ' <str> <jd> 그 그려 김영민은 근대 전환기의 대표적인 서사 양식을 <end>'),
#  ('i mean we ve got a bad temper but we ve got a bad temper and i ve got a bad temper too .',
#   ' <str> <cc> 그 또 성격도 급한데 우리 이름 이 아빠도 성격 급한데 나도 쫌 성격이 급하기는 급한데 <end>'),
#  ('i think they re a little smart because they re still in the new song on ballard s side .',
#   ' <str> <jd> 지금도 신곡 나오는 거 보면은 발라드 쪽 이런 노래들이라 걔네가 쫌 똑똑한 것 같아요 <end>'),
#  ('how much snow did it snow it was all over my moms knee',
#   ' <str> <jd> 눈이 눈이 얼마나 많이 왔는가 엄마 무르배까지 찼었어 . <end>'),
#  ('if you use another app you can record it at the same time when you listen to a lecture so there are some handwriting coming out depending on the recorded part',
#   ' <str> <jd> 이제 따른 어플 이용하면은 뭐 강의 들을 때 동시에 녹음도 가능해서 그 녹음한 부분에 따라서 이제 필기가 나오는 것도 있거든요 . <end>'),
#  ('no i ve never seen mr . name before .', ' <str> <kw> 네 이름씨가 츰이예요 . <end>'),
#  ('uh so they re just gonna bark or something ?',
#   ' <str> <jj> 어 게믄 걔네가 막 갑자기 짖거나 그럴건가 ? <end>'),
#  ('you see that sweat flowing like a marble ?',
#   ' <str> <kw> 땀이 구슬같이 흐르는 거 보예 ? <end>'),
#  ('do you have a brother ?', ' <str> <kw> 싱야 계세요 ? <end>'),
#  ('its characterized by investing a lot',
#   ' <str> <jd> 투자를 많이 하는 것이 특징이여 . <end>'),
#  ('what are you doing ?', ' <str> <kw> 왜 자꼬 이래 ? <end>'),
#  ('he s a bad guy .', ' <str> <kw> 저 녀석은 질이 매한 놈이야 . <end>'),
#  ('he said bonan young but he said it would be absolutely nice',
#   ' <str> <jj> 그가 보난 영 했데 말 해질쿠가 하는 말이주 . <end>'),
#  ('i m gonna take it out .', ' <str> <jj> 테이크아웃 하젠 <end>'),
#  ('well because of that', ' <str> <jj> 음 게난 <end>'),
#  ('don t you think that s just happened these days ?',
#   ' <str> <gs> 그 요새는 막 극장판 막 그런 것도 나온다 아이가 ? <end>'),
#  ('you don t know if you ve heard of more than that dynamite ?',
#   ' <str> <jd> 방탄소년단 그 다이나마이트 말고 또 많이 들어봤는지 모르겄네 ? <end>'),
#  ('she s the only one who knows about it .',
#   ' <str> <jd> 나 하트 시그널 하나도 안봐가꼬 그거 걔만 알아 임현주랑 <end>'),
#  ('that s him isn t he ? mom did he do this to you ?',
#   ' <str> <kw> 그 아이씨지 ? 엄마 . 그 자석이 엄마 이렇게 했지 ? <end>'),
#  ('yes i put on sunscreen', ' <str> <jj> 어 썬크림 발란 . <end>'),
#  ('it s because of the deal because of the responsibility .',
#   ' <str> <jj> 계약 허난에 또 그 책임감 때문에이 <end>'),
#  ('so when i saw something like that', ' <str> <gs> 그래서 저는 그런 걸 봤을 때 쫌 <end>'),
#  ('i cant eat spicy food well but its delicious with spicy lamb',
#   ' <str> <jj> 매운건 잘 못 먹는디 양 경해도 매운 고추가 들어가야 맛좋아 . <end>'),
#  ('yeah that s how i opened it .', ' <str> <jj> 그래 이렇게 해서 열어줜 <end>'),
#  ('the vineyard was falling apart .',
#   ' <str> <kw> 그 포도밭은 완정이 폐허가 되어 가고 있었어 . <end>'),
#  ('or else you ll have to spend the rest of your life to night scraping .',
#   ' <str> <kw> 안 그럼 평상 박버 박바가지 긁히고 산다더구만 . <end>'),
#  ('my fatherinlaw is a little more personal than my motherinlaw',
#   ' <str> <jd> 시어머니보다는 시아버지님이 쫌 성격이 좀 <end>'),
#  ('couples are equal .', ' <str> <kw> 에펜사나는 동등한 거야 . <end>'),
#  ('i m not the lead surgeon today .', ' <str> <kw> 오늘 집도의는 내가 아니에요 . <end>'),
#  ('it has a great role such as assisting the parking',
#   ' <str> <jd> 그 주차를 보조하는 등 훌륭한 역할을 가지고 있댜 . <end>'),
#  ('it s obvious isn t it ?', ' <str> <jj> 당연한 거 아니 ? <end>'),
#  ('and then i let you down and if you re upset that i m sorry',
#   ' <str> <cc> 그리고 나서 내가 숙였어 미안하다고 니가 기분 나빴다면 <end>'),
#  ('i want to sleep forever .', ' <str> <kw> 끝없이 잠을 자구 싶어요 . <end>'),
#  ('yeah come here .', ' <str> <kw> 네 일루 오세요 . <end>'),
#  ('as a fan i wanted to be a little sad and a little better .',
#   ' <str> <kw> 팬으로서 쫌 아쉽고 쫌 더 잘 됐으면 좋겠다라는 마음이 크긴 했지만 <end>'),
#  ('i m on my way .', ' <str> <jj> 다니는데 이 <end>'),
#  ('imam coming again on chuseok so mom did something so delicious',
#   ' <str> <jj> 요번에도 추석 때 오난이네 엄마 너무 맛 존거 해줘부난 <end>'),
#  ('i can t talk to you like you re a thief .',
#   ' <str> <jd> 도둑 도둑이라고 할까 봐 내가 말을 못 하겄다 . <end>'),
#  ('so uh you should ve done some kachi then but i d like it to be me .',
#   ' <str> <cc> 어 그래서 쫌 어 그때 캐치를 했었어야 되는데 내가 돼갖구 좋겠네 음 <end>'),
#  ('it s just a neat looking style and i don t like it that way .',
#   ' <str> <jd> 그냥 깔끔해 보이는 스타일 예 너무 단정한 건 또 그거 그 나름대로 또 막 싫고 긍까 <end>'),
#  ('its like young unlike the movie its a little calm its a little melodrama',
#   ' <str> <jd> 음 영 영화랑 다르게 쫌 잔 잔잔하고 약간 멜로드라마 약간 <end>'),
#  ('itont come even if i wait a long time why arent you',
#   ' <str> <jj> 한참이나 기다려도 안오는 거라 . 무사안왐시 거난예 <end>'),
#  ('i m just saying i don t like it so like three or four months ?',
#   ' <str> <jd> 막 그러니까 참 싫은 거 같애요 그까 좀 한 삼사월 ? <end>'),
#  ('just cause i m so good at it i m gonna use my husband as a shutter man .',
#   ' <str> <jd> 내가 그릏게 잘 나간다고 해서 내 남편을 난 셔터 맨으로 쓸 <end>'),
#  ('i ll come see you later .', ' <str> <kw> 냉중에 놀러오구 . <end>'),
#  ('in the cold winters wear them hot .',
#   ' <str> <kw> 찬 바람이 부는 게울게는 따듯하게 입고 다니세요 . <end>'),
#  ('do you want me to recommend that ?', ' <str> <gs> 그거 내 추천해 줄까 ? <end>'),
#  ('i think i m feeling a little bit more now .',
#   ' <str> <kw> 지금 와서 조금 많이 느끼는 거 같애 . <end>'),
#  ('the boy and the girl took turns lining up .',
#   ' <str> <kw> 바지씨 아이와 예자 아이가 번갈아 가며 줄을 지었다 . <end>'),
#  ('it s not hormones it s nerves it s nerves it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells it s cells .',
#   ' <str> <cc> 어 이 치료를 해서 수술 어느 신경 신경이라고 하더라 호르몬이 아니고 어느 신경을 이케 <end>'),
#  ('iveather is old right',
#   ' <str> <jj> 나 저번부터 말 했네 화장실이 있네 칼호텔 진짜 오래된 거 알지 ? <end>'),
#  ('go sit down .', ' <str> <jj> 강 앉아 우리 아방이 <end>'),
#  ('i didn t do it with both crutches .',
#   ' <str> <jj> 이게 그 땐예 양쪽 목발도 짚엉 아예 못 해난 . <end>'),
#  ('i think it s the right thing to do with your motivation .',
#   ' <str> <cc> 동기 생활 쪽으로 가는 게 맞는 거 같다고 쫌 <end>'),
#  ('you just went because you had plans for the kids .',
#   ' <str> <kw> 애들 약속있다고 기양 갔잖아요 . <end>'),
#  ('where are the kids moving ?', ' <str> <kw> 엄만 애들 어디 이민 가우 ? <end>'),
#  ('because he studied he took it to a career of kids who studied and then he bought his friends .',
#   ' <str> <kw> 아부지는 공부를 했기 때문에 공부하는 출세한 애들의 삶에 갖다가 자기 친구들을 살면 봤단 말이지 . <end>'),
#  ('today s judge is our eternal boss our eternal big brother .',
#   ' <str> <kw> 오눌의 심사위원은 우리의 영원한 보스 우리의 영원한 큰 형님 . <end>'),
#  ('they re going to take the bull and eat it .',
#   ' <str> <kw> 화쇠를 잡아서 먹으려고 한다 . <end>'),
#  ('tick tocking ?', ' <str> <kw> 깍디기요 ? <end>'),
#  ('i m a kid now but when your friends come to me you re a complete bitch .',
#   ' <str> <kw> 이제 연년생이니까 근데 누나 친구들이 나한테 오면은 너 누나랑 완전 판백이라고 <end>'),
#  ('the woman who reads .', ' <str> <kw> 책읽어주는 예자 <end>'),
#  ('that s how you do it .', ' <str> <jj> 겅 허난이 아이고 <end>'),
#  ('there are craters on the moon s surface .',
#   ' <str> <kw> 달 표면에는 분화구들이 패여 있사 . <end>'),
#  ('but it s not that bad .', ' <str> <kw> 하이간 칠칠맞기는 . <end>'),
#  ('i bought it and he said he wanted my mom to buy one too',
#   ' <str> <jd> 샀더니 옆에서 우리 엄마 것도 하나 샀으믄하고 뭉기적뭉기적대고 <end>'),
#  ('as you get older you have to move your body more put it on',
#   ' <str> <jj> 나이 먹을수록 몸을 더 움직여사주 가만히 이시믄 <end>'),
#  ('just doing a mukbang show with your eyes is the right character for you',
#   ' <str> <jj> 그냥 눈으로 먹방 쇼 하는 거 딱 너한테 어울리는 캐릭터아냐 . <end>'),
#  ('i m just saying she s out of her mind and i m always trying to figure it out .',
#   ' <str> <kw> 하다 보니까 애가 아가 정신을 못 차리는 거야 내가 맨날 <end>'),
#  ('nothing special but one drink first .',
#   ' <str> <kw> 특별한 근 없지만 우선 한 잔 . <end>'),
#  ('whatever you want .', ' <str> <kw> 아휴 마음대루 해요 . 마음대루 <end>'),
#  ('the forest is weeping .', ' <str> <kw> 숲이 우거차다 . <end>'),
#  ('there was a spark in my eyes .', ' <str> <kw> 내 눈에서 불꽃이 뼈떡 튀었다고요 . <end>'),
#  ('i don t know i ve had two or three cans of beer almost once a week .',
#   ' <str> <jd> 모르겠어 지금 이르케 맥주도 거의 일주일에 두세 번 두세 캔을 먹었어요 예전에는 근데 지금은 <end>'),
#  ('can t i marry my dad ?', ' <str> <kw> 아부지랑 겨론하면 안 돼요 ? <end>'),
#  ('he told me not to come home with you guys .',
#   ' <str> <jj> 너네랑 내령 집에 오지 말래 <end>'),
#  ('it s too bad it s like it s an but it s a .',
#   ' <str> <kw> 팔십 점이면 졸업인데 칠십구점이라니 너무 아까바요 . <end>'),
#  ('i just asked your friend to call my brother and he called me to tell me what s going on and as soon as i showed him',
#   ' <str> <jd> 오빠 친구한테 우리 오빠 좀 불러 달라고 막 우니까 오빠 친구가 무슨 일이냐구 하믄서 우리 오빠를 불러줬는데 그 보여주자마자 <end>'),
#  ('did you play the game', ' <str> <jj> 게임 핸 ? <end>'),
#  ('i ve never seen anything like that before . i ve never seen anything like it .',
#   ' <str> <kw> 나는 그거 처음 봤잖아 그 가위같이 생긴 바리깡 처음 봐 가주고 그걸로 짜르더라고 <end>'),
#  ('would you like me to bring them together ?',
#   ' <str> <kw> 한사람인데 몰과 한군데로 모아 줄까요 ? <end>'),
#  ('how patheticly stupid of you to do something like that .',
#   ' <str> <kw> 그 따우 일을 하다니 얼맨큼 한심한 바보짓이냐 . <end>'),
#  ('i took a little walk to work .', ' <str> <kw> 개구운 걸음걸이로 출근을 했어 . <end>'),
#  ('did she teach you', ' <str> <jj> 그 언니가 너한테 가르쳐줜 ? <end>'),
#  ('there s a lot of noise about whether or not you ve boiled a railroad box .',
#   ' <str> <kw> 기차화통을 삶아먹었는지 소래기통이 크다 . <end>'),
#  ('oh no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no no .',
#   ' <str> <jd> 어 이름언니야 멋있어 . <end>'),
#  ('so now i m retired and i m building a first class store on the ground floor .',
#   ' <str> <kw> 그래서 짐 정년퇴직하고 밑에 일 층에 걔네 건물에 수석 가게를 차렸어 . <end>'),
#  ('what do you work hard for ?', ' <str> <kw> 머를 열심히 하와 ? <end>'),
#  ('so maybe if the beach goes to the cable car again it s going to be a little bit unusual .',
#   ' <str> <kw> 그니까 아마 바닷가가 또 케이블카 타면은 쫌 특이한 그런 <end>'),
#  ('everybody just pulls their bikes up the mountain .',
#   ' <str> <kw> 마카 그냥 자전거 끌구 산에 올라가 그러면은 <end>'),
#  ('no the menu came out at', ' <str> <jj> 아니야 열 두시 반에 메뉴가 나완 . <end>'),
#  ('it smells like gas . it s young .', ' <str> <kw> 가스 냄새를 맡아 어리해지다 . <end>'),
#  ('twenty two what ?', ' <str> <kw> 이십 이 뭐이 ? <end>'),
#  ('hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey hey .',
#   ' <str> <jd> 야 오빠 이럴 때있는데 뭐 기분이 나쁘진 않드라고 . <end>'),
#  ('i didn t call you . i went to pick you up .',
#   ' <str> <kw> 즌화하지 그랬어요 데릴러 갔지 . <end>'),
#  ('you took off one laugh', ' <str> <jj> 한 개 벗견 . 웃음 <end>'),
#  ('you have to try to go back .', ' <str> <kw> 돌아가려고 스시로가 노력해야 해요 . <end>'),
#  ('i want to eat sweet potatoes so', ' <str> <jj> 나는 고구마가 먹고 싶은디 겅행 <end>'),
#  ('but at the end did you quit a little bad ?',
#   ' <str> <jd> 근데 마지막에 쫌 안 좋게 그만뒀었나 ? <end>'),
#  ('like nothing happened to each other .', ' <str> <kw> 서름 아문 일 없던 것처럼 <end>'),
#  ('do you have any experience with that ?',
#   ' <str> <jd> 그때 나는 쫌 싫었어 혹시 너는 그런 경험이 있니 ? <end>'),
#  ('you keep turning around or there s no dentist and there s no dentist and there s no dentist .',
#   ' <str> <jd> 계속 오빠 돌고 아니면은 쩌기 무슨 어디 치과 이런 데다가 그 <end>'),
#  ('i have to change it to something else and i think i m going to buy these shoes in advance and i m going to buy them in advance .',
#   ' <str> <jd> 다른 걸로 바꿔야 하는데 이 신발 미리 사 놓까 이런 생각도 하고 미리 사 놓기도 하죠 . <end>'),
#  ('it s been a while .', ' <str> <kw> 잰작 좀 반성하지 . <end>'),
#  ('you re the first person i ve ever seen in my life .',
#   ' <str> <kw> 옛날 보듬 안동권씨라면 일로 쳐줬거든 . <end>'),
#  ('i put it up in the middle of the incentive .',
#   ' <str> <jj> 인덕션 딱 가운데 행으네 올령 먹언 ? <end>'),
#  ('when i was a kid i used to love chicken .',
#   ' <str> <jd> 또 치킨도 사가지고 왔다고 어렸을 때 치킨은 허벌나게 좋아하긴 했는데 <end>'),
#  ('i don t know if it ll be a little sad if you don t give it to me .',
#   ' <str> <jd> 주믄 좋아라 허고 안 주믄 쪼까 서운할랑가 모르겠어 그런데 <end>'),
#  ('yesterday was a short dressed day .', ' <str> <kw> 어재는 단옷날이었다 . <end>'),
#  ('and you . . .', ' <str> <kw> 그러고 형이 <end>'),
#  ('farming too', ' <str> <jj> 농사도예 <end>'),
#  ('just marry your uncle here .',
#   ' <str> <kw> 가지마시구 그냥 외삼촌이랑 여개서 결론해서 사세요 . <end>'),
#  ('you re gonna have to look for me too .',
#   ' <str> <jd> 나도 쫌 찾아보게 되더라구 그리구 <end>'),
#  ...]

# %%
cleaned_corpus[:1]
# Out:
# [('it s not my country s name corian .',
#   ' <str> <kw> 그 털이 쫌 덜 빠지는 게 우리나라 그 코리안 숏이라고 뭔 뭐드라 이름 <end>')]

# %%
len(cleaned_corpus)
# Out:
# 678066

# %%
# 최종적으로 ko_tokenizer 과 en_tokenizer 를 얻기
# enc_tokenizer에는 set_encode_extra_options("bos:eos") 함수를 실행해 타겟 입력이 문장의 시작 토큰과 끝 토큰을 포함할 수 있게
# 단어 사전을 매개변수로 받아 원하는 크기의 사전을 정의할 수 있게 합니다. (기본: 20,000)
# 학습 후 저장된 model 파일을 SentencePieceProcessor() 클래스에 Load()한 후 반환합니다.
# 특수 토큰의 인덱스를 아래와 동일하게 지정합니다.
# <PAD> : 0 / <BOS> : 1 / <EOS> : 2 / <UNK> : 3
# <jj> : 4 / <jd> : 5 / <gs> : 6 / <cc> : 7 / <kw> : 8

# Sentencepiece를 활용하여 학습한 tokenizer를 생성
def generate_tokenizer(corpus, vocab_size, lang="en", pad_id=0, bos_id=1, eos_id=2, unk_id=3):

    temp_file = os.getenv('HOME') + f'/aiffel/aiffelthon/corpus_{lang}.txt'     # corpus를 받아 txt파일로 저장
    
    with open(temp_file, 'w') as f:
        for row in corpus:
            f.write(str(row) + '\n')
    
    # Sentencepiece를 이용해 
    spm.SentencePieceTrainer.Train(
        f'--input={temp_file} --model_type=bpe --pad_id={pad_id} --bos_id={bos_id} --eos_id={eos_id} \
        --unk_id={unk_id} --model_prefix=spm{lang}_r0 --vocab_size={vocab_size} \
        --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false'   # model_r1
    )
    tokenizer = spm.SentencePieceProcessor()
    tokenizer.Load(f'spm{lang}_r0.model') # model_r1

    return tokenizer

# %%
SRC_VOCAB_SIZE = TGT_VOCAB_SIZE = 25000

enc_corpus = []
dec_corpus = []

for pair in cleaned_corpus:
    e, d = pair[0], pair[1]
    # enc, dec 분리
    enc_corpus.append(e)
    dec_corpus.append(d)

enc_tokenizer = generate_tokenizer(enc_corpus, SRC_VOCAB_SIZE, "enc")
dec_tokenizer = generate_tokenizer(dec_corpus, TGT_VOCAB_SIZE, "dec")
# dec_tokenizer.set_encode_extra_options("bos:eos")
# Out:
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=/aiffel/aiffel/aiffelthon/corpus_enc.txt --model_type=bpe --pad_id=0 --bos_id=1 --eos_id=2         --unk_id=3 --model_prefix=spmenc_r0 --vocab_size=25000         --user_defined_symbols=<jj>,<jd>,<gs>,<cc>,<kw> --remove_extra_whitespaces=false
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /aiffel/aiffel/aiffelthon/corpus_enc.txt
#   input_format:
#   model_prefix: spmenc_r0
#   model_type: BPE
#   vocab_size: 25000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   user_defined_symbols: <jj>
#   user_defined_symbols: <jd>
#   user_defined_symbols: <gs>
#   user_defined_symbols: <cc>
#   user_defined_symbols: <kw>
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
#   bos_id: 1
#   eos_id: 2
#   pad_id: 0
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 0
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(329) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(178) LOG(INFO) Loading corpus: /aiffel/aiffel/aiffelthon/corpus_enc.txt
# trainer_interface.cc(385) LOG(INFO) Loaded all 678065 sentences
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <pad>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jj>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <jd>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <gs>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <cc>
# trainer_interface.cc(400) LOG(INFO) Adding meta_piece: <kw>
# trainer_interface.cc(405) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(466) LOG(INFO) all chars count=38985803
# trainer_interface.cc(477) LOG(INFO) Done: 99.9549% characters are covered.
# trainer_interface.cc(487) LOG(INFO) Alphabet size=27
# trainer_interface.cc(488) LOG(INFO) Final character coverage=0.999549
# trainer_interface.cc(520) LOG(INFO) Done! preprocessed 678065 sentences.
# trainer_interface.cc(526) LOG(INFO) Tokenizing input sentences with whitespace: 678065
# trainer_interface.cc(537) LOG(INFO) Done! 39240
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1183253 min_freq=1
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=325509 size=20 all=1153 active=1125 piece=▁l
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=141448 size=40 all=1872 active=1844 piece=ke
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=98324 size=60 all=2756 active=2728 piece=▁in
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=62202 size=80 all=3694 active=3666 piece=ot
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=52478 size=100 all=4348 active=4320 piece=oo
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=52354 min_freq=1182
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=43146 size=120 all=5135 active=1718 piece=▁with
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=35594 size=140 all=5596 active=2179 piece=▁are
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=28888 size=160 all=6547 active=3130 piece=ly
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=24260 size=180 all=7045 active=3628 piece=im
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=20027 size=200 all=7657 active=4239 piece=▁any
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=19941 min_freq=1403
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=17120 size=220 all=8152 active=1485 piece=ind
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=14581 size=240 all=8653 active=1986 piece=mp
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=13356 size=260 all=9269 active=2602 piece=el
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=11443 size=280 all=10173 active=3506 piece=▁year
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=10494 size=300 all=10560 active=3893 piece=ul
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=10440 min_freq=1304
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=9539 size=320 all=11170 active=1515 piece=and
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=8607 size=340 all=11571 active=1916 piece=▁first
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7693 size=360 all=12030 active=2375 piece=▁by
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=7149 size=380 all=12691 active=3035 piece=▁talk
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=6464 size=400 all=13039 active=3383 piece=▁off
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=6417 min_freq=1113
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5896 size=420 all=13382 active=1335 piece=▁car
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5524 size=440 all=13779 active=1732 piece=▁done
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=5250 size=460 all=14250 active=2203 piece=▁de
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4974 size=480 all=14669 active=2622 piece=▁father
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4638 size=500 all=15024 active=2977 piece=▁stud
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=4622 min_freq=979
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4432 size=520 all=15313 active=1285 piece=▁ph
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=4135 size=540 all=15640 active=1612 piece=▁happen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3941 size=560 all=16061 active=2033 piece=▁middle
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3758 size=580 all=16439 active=2411 piece=▁sick
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3488 size=600 all=16770 active=2742 piece=▁may
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=3478 min_freq=886
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3329 size=620 all=17013 active=1235 piece=▁young
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3191 size=640 all=17187 active=1409 piece=ner
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=3045 size=660 all=17689 active=1911 piece=▁everything
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2910 size=680 all=17892 active=2114 piece=hed
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2836 size=700 all=18265 active=2487 piece=▁ever
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2833 min_freq=784
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2685 size=720 all=18504 active=1237 piece=▁sha
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2583 size=740 all=18885 active=1618 piece=▁watch
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2485 size=760 all=19419 active=2152 piece=▁sudden
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2416 size=780 all=19631 active=2364 piece=where
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2336 size=800 all=19938 active=2671 piece=▁asked
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=2326 min_freq=704
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2249 size=820 all=20214 active=1277 piece=▁met
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2163 size=840 all=20493 active=1556 piece=▁heal
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2109 size=860 all=20746 active=1809 piece=ult
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2051 size=880 all=20891 active=1954 piece=man
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=2002 size=900 all=21367 active=2430 piece=ream
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1995 min_freq=595
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1927 size=920 all=21625 active=1311 piece=▁expensive
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1874 size=940 all=21983 active=1669 piece=▁kore
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1772 size=960 all=22326 active=2012 piece=▁comes
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1700 size=980 all=22542 active=2228 piece=▁chicken
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1648 size=1000 all=22654 active=2340 piece=▁changed
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1641 min_freq=515
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1602 size=1020 all=22830 active=1309 piece=llow
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1561 size=1040 all=23021 active=1500 piece=▁telling
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1519 size=1060 all=23320 active=1799 piece=▁unc
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1468 size=1080 all=23654 active=2133 piece=ular
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1410 size=1100 all=23890 active=2369 piece=▁clock
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1409 min_freq=447
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1368 size=1120 all=24124 active=1426 piece=ars
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1319 size=1140 all=24515 active=1817 piece=▁drama
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1282 size=1160 all=24799 active=2101 piece=ona
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1236 size=1180 all=24969 active=2271 piece=cks
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1207 size=1200 all=25262 active=2564 piece=▁meeting
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1206 min_freq=388
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1167 size=1220 all=25486 active=1487 piece=▁follow
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1134 size=1240 all=25657 ac
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_557/3971865850.py in <module>
#      10     dec_corpus.append(d)
#      11
# ---> 12 enc_tokenizer = generate_tokenizer(enc_corpus, SRC_VOCAB_SIZE, "enc")
#      13 dec_tokenizer = generate_tokenizer(dec_corpus, TGT_VOCAB_SIZE, "dec")
#      14 # dec_tokenizer.set_encode_extra_options("bos:eos")
#
# /tmp/ipykernel_557/319613257.py in generate_tokenizer(corpus, vocab_size, lang, pad_id, bos_id, eos_id, unk_id)
#      17
#      18     # Sentencepiece를 이용해
# ---> 19     spm.SentencePieceTrainer.Train(
#      20         f'--input={temp_file} --model_type=bpe --pad_id={pad_id} --bos_id={bos_id} --eos_id={eos_id} \
#      21         --unk_id={unk_id} --model_prefix=spm{lang}_r0 --vocab_size={vocab_size} \
#
# /opt/conda/lib/python3.9/site-packages/sentencepiece/__init__.py in Train(arg, **kwargs)
#     405       """Train Sentencepiece model. Accept both kwargs and legacy string arg."""
#     406       if arg is not None and type(arg) is str:
# --> 407         return SentencePieceTrainer._TrainFromString(arg)
#     408
#     409       def _encode(value):
#
# /opt/conda/lib/python3.9/site-packages/sentencepiece/__init__.py in _TrainFromString(arg)
#     383     @staticmethod
#     384     def _TrainFromString(arg):
# --> 385         return _sentencepiece.SentencePieceTrainer__TrainFromString(arg)
#     386
#     387     @staticmethod
#
# KeyboardInterrupt:
# tive=1658 piece=▁road
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1096 size=1260 all=25840 active=1841 piece=▁weight
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1070 size=1280 all=26152 active=2153 piece=iet
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1027 size=1300 all=26422 active=2423 piece=che
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=1024 min_freq=337
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=1003 size=1320 all=26692 active=1512 piece=em
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=990 size=1340 all=26939 active=1759 piece=▁minutes
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=967 size=1360 all=27208 active=2028 piece=▁cute
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=941 size=1380 all=27378 active=2198 piece=ical
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=923 size=1400 all=27538 active=2358 piece=anger
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=923 min_freq=300
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=906 size=1420 all=27846 active=1671 piece=▁profess
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=881 size=1440 all=27967 active=1792 piece=arra
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=866 size=1460 all=28176 active=2001 piece=▁floor
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=848 size=1480 all=28383 active=2208 piece=▁hungry
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=835 size=1500 all=28468 active=2293 piece=▁dist
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=834 min_freq=273
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=821 size=1520 all=28577 active=1519 piece=▁team
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=805 size=1540 all=28713 active=1655 piece=▁paid
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=784 size=1560 all=28973 active=1915 piece=ations
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=770 size=1580 all=29216 active=2158 piece=▁whether
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=750 size=1600 all=29358 active=2300 piece=head
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=749 min_freq=247
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=737 size=1620 all=29606 active=1685 piece=icked
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=725 size=1640 all=29885 active=1964 piece=▁learned
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=712 size=1660 all=30010 active=2089 piece=▁talked
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=695 size=1680 all=30306 active=2385 piece=ters
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=676 size=1700 all=30569 active=2648 piece=ned
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=676 min_freq=223
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=664 size=1720 all=30635 active=1565 piece=min
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=647 size=1740 all=30902 active=1832 piece=▁adv
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=637 size=1760 all=31037 active=1967 piece=▁enj
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=618 size=1780 all=31295 active=2225 piece=ins
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=605 size=1800 all=31537 active=2467 piece=▁others
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=604 min_freq=205
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=595 size=1820 all=31764 active=1804 piece=pose
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=587 size=1840 all=31863 active=1903 piece=▁trust
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=581 size=1860 all=31954 active=1994 piece=▁det
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=565 size=1880 all=32154 active=2194 piece=▁east
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=554 size=1900 all=32351 active=2391 piece=ike
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=554 min_freq=190
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=549 size=1920 all=32522 active=1764 piece=▁places
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=536 size=1940 all=32664 active=1906 piece=▁gar
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=528 size=1960 all=32999 active=2241 piece=▁basic
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=514 size=1980 all=33142 active=2384 piece=kend
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=503 size=2000 all=33255 active=2497 piece=lly
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=503 min_freq=176
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=494 size=2020 all=33468 active=1846 piece=▁origin
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=490 size=2040 all=33549 active=1927 piece=▁character
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=475 size=2060 all=33685 active=2063 piece=▁stress
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=468 size=2080 all=33786 active=2164 piece=▁finish
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=458 size=2100 all=33872 active=2250 piece=▁strength
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=457 min_freq=163
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=449 size=2120 all=33945 active=1765 piece=par
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=442 size=2140 all=34108 active=1928 piece=angu
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=436 size=2160 all=34318 active=2138 piece=▁stor
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=429 size=2180 all=34454 active=2274 piece=ined
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=419 size=2200 all=34604 active=2424 piece=▁hy
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=419 min_freq=152
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=414 size=2220 all=34779 active=1874 piece=▁stubborn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=405 size=2240 all=34825 active=1920 piece=▁flower
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=397 size=2260 all=34974 active=2069 piece=▁smoke
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=390 size=2280 all=35120 active=2215 piece=inese
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=383 size=2300 all=35278 active=2373 piece=▁king
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=383 min_freq=141
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=376 size=2320 all=35474 active=1956 piece=▁definitely
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=369 size=2340 all=35557 active=2039 piece=ately
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=363 size=2360 all=35697 active=2179 piece=▁area
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=359 size=2380 all=35732 active=2214 piece=▁cancer
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=355 size=2400 all=35802 active=2284 piece=▁beer
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=355 min_freq=131
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=349 size=2420 all=35962 active=1949 piece=▁ref
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=342 size=2440 all=36166 active=2153 piece=▁phy
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=335 size=2460 all=36295 active=2282 piece=rage
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=332 size=2480 all=36414 active=2401 piece=▁bull
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=327 size=2500 all=36585 active=2572 piece=▁sacrifice
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=327 min_freq=123
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=319 size=2520 all=36762 active=2006 piece=▁waste
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=313 size=2540 all=36886 active=2130 piece=umn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=309 size=2560 all=36972 active=2216 piece=▁rot
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=305 size=2580 all=37083 active=2327 piece=▁heat
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=301 size=2600 all=37200 active=2444 piece=▁shouldnt
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=300 min_freq=115
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=296 size=2620 all=37223 active=1883 piece=▁turning
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=292 size=2640 all=37409 active=2069 piece=▁prepare
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=288 size=2660 all=37436 active=2096 piece=llen
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=285 size=2680 all=37499 active=2159 piece=▁scream
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=281 size=2700 all=37573 active=2233 piece=▁divorced
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=280 min_freq=110
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=278 size=2720 all=37673 active=1979 piece=▁environ
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=274 size=2740 all=37802 active=2108 piece=▁join
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=269 size=2760 all=37941 active=2247 piece=▁bone
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=265 size=2780 all=37989 active=2295 piece=▁detail
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=261 size=2800 all=38064 active=2370 piece=cha
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=261 min_freq=104
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=257 size=2820 all=38220 active=1996 piece=▁wild
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=253 size=2840 all=38299 active=2075 piece=▁stars
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=251 size=2860 all=38392 active=2168 piece=▁terrible
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=248 size=2880 all=38528 active=2304 piece=▁dollar
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=244 size=2900 all=38639 active=2415 piece=mosp
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=244 min_freq=97
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=241 size=2920 all=38778 active=2069 piece=▁frustrated
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=238 size=2940 all=38856 active=2147 piece=aring
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=235 size=2960 all=39017 active=2308 piece=▁original
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=231 size=2980 all=39081 active=2372 piece=ek
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=229 size=3000 all=39223 active=2514 piece=▁webtoon
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=229 min_freq=92
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=226 size=3020 all=39237 active=1976 piece=▁sheep
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=222 size=3040 all=39336 active=2075 piece=▁bang
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=218 size=3060 all=39400 active=2139 piece=▁cong
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=216 size=3080 all=39564 active=2303 piece=brary
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=214 size=3100 all=39685 active=2424 piece=▁pour
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=214 min_freq=88
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=212 size=3120 all=39715 active=2013 piece=▁seventy
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=209 size=3140 all=39860 active=2158 piece=lo
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=207 size=3160 all=40052 active=2350 piece=▁plent
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=204 size=3180 all=40107 active=2405 piece=lla
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=202 size=3200 all=40203 active=2501 piece=ilies
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=202 min_freq=83
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=200 size=3220 all=40288 active=2094 piece=▁hadn
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=198 size=3240 all=40300 active=2106 piece=fish
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=196 size=3260 all=40396 active=2202 piece=▁alley
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=195 size=3280 all=40429 active=2235 piece=▁steamed
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=192 size=3300 all=40470 active=2276 piece=▁nep
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=192 min_freq=80
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=190 size=3320 all=40511 active=2063 piece=rows
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=189 size=3340 all=40582 active=2134 piece=▁novel
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=187 size=3360 all=40634 active=2186 piece=▁faces
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=185 size=3380 all=40768 active=2320 piece=▁return
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=183 size=3400 all=40829 active=2381 piece=▁breathe
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=183 min_freq=76
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=181 size=3420 all=40908 active=2121 piece=▁negative
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=179 size=3440 all=41117 active=2330 piece=▁cooked
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=178 size=3460 all=41216 active=2429 piece=▁thoughts
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=176 size=3480 all=41309 active=2522 piece=▁series
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=174 size=3500 all=41433 active=2646 piece=▁unusual
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=174 min_freq=73
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=172 size=3520 all=41517 active=2155 piece=▁heaven
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=170 size=3540 all=41603 active=2241 piece=▁ability
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=168 size=3560 all=41671 active=2309 piece=▁forever
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=166 size=3580 all=41762 active=2400 piece=▁peace
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=163 size=3600 all=41810 active=2448 piece=▁va
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=163 min_freq=69
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=162 size=3620 all=41971 active=2240 piece=▁upper
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=160 size=3640 all=42047 active=2316 piece=▁benef
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=158 size=3660 all=42165 active=2434 piece=reak
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=157 size=3680 all=42257 active=2526 piece=iment
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=155 size=3700 all=42373 active=2642 piece=▁buys
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=155 min_freq=66
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=154 size=3720 all=42420 active=2166 piece=▁locked
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=152 size=3740 all=42498 active=2244 piece=uietly
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=151 size=3760 all=42595 active=2341 piece=▁perfor
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=149 size=3780 all=42693 active=2439 piece=▁copy
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=147 size=3800 all=42757 active=2503 piece=▁neung
# bpe_model_trainer.cc(167) LOG(INFO) Updating active symbols. max_freq=147 min_freq=63
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=146 size=3820 all=42761 active=2140 piece=▁studies
# bpe_model_trainer.cc(258) LOG(INFO) Added: freq=144 size

# %%
eng_corpus[100]

# %%
kor_corpus[100]

# %%
# Test data
SRC_VOCAB_SIZE = TGT_VOCAB_SIZE = 25000

eng_corpus_test = []
kor_corpus_test = []

for pair in cleaned_corpus_test:
    k, e = pair[0], pair[1]
    # kor, eng 나눠서 데이터 정제 후 분리
    kor_corpus_test.append(preprocess_sentence(k))
    eng_corpus_test.append(preprocess_sentence(e))

# en_test_tokenizer = generate_tokenizer(eng_corpus, SRC_VOCAB_SIZE, "en")
# ko_test_tokenizer = generate_tokenizer(kor_corpus, TGT_VOCAB_SIZE, "ko")
# ko_test_tokenizer.set_encode_extra_options("bos:eos")

# %%
# eng_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in eng_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(eng_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in eng_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()

# %%
# kor_corpus 통계

min_len = 999
max_len = 0
sum_len = 0


for sen in kor_corpus:
    length = len(sen)
    if min_len > length: min_len = length
    if max_len < length: max_len = length
    sum_len += length

print("문장의 최단 길이:", min_len)
print("문장의 최장 길이:", max_len)
print("문장의 평균 길이:", sum_len // len(kor_corpus))

sentence_length = np.zeros((max_len), dtype=int)

#총 max_len의 배열을 만든 후, raw 문장을 돌면서 각 문장별 길이를 sentence_length의 len(sen) 인덱스마다  계속 더해가면서 counting
for sen in kor_corpus:
    sentence_length[len(sen)-1] += 1

plt.bar(range(max_len), sentence_length, width=1.0)
plt.title("Sentence Length Distribution")
plt.show()

# %%
# max_tokens = np.mean(num_tokens) + 2.5 * np.std(num_tokens)
# maxlen = int(max_tokens)
# print('pad_sequences maxlen : ', maxlen)
# print(f'전체 문장의 {np.sum(num_tokens < max_tokens) / len(num_tokens)*100}%가 maxlen 설정값 이내에 포함됩니다.')

# %%
# 토크나이저를 활용해 토큰의 길이가 50 이하인 데이터를 선별하여 src_corpus 와 tgt_corpus 를 각각 구축하고, 텐서 enc_train 과 dec_train 으로 변환
src_corpus = [] #영어
tgt_corpus = [] #한글

assert len(kor_corpus) == len(eng_corpus)

# 토큰의 길이가 xxx 이하인 문장만 남깁니다. 
for idx in tqdm(range(len(kor_corpus))):
    src = en_tokenizer.EncodeAsIds(eng_corpus[idx])
    tgt = ko_tokenizer.EncodeAsIds(kor_corpus[idx])
    
    if len(src) <= 120 and len(tgt) <= 100: 
        src_corpus.append(src)
        tgt_corpus.append(tgt)

# 패딩처리를 완료하여 학습용 데이터를 완성합니다. 
enc_train = tf.keras.preprocessing.sequence.pad_sequences(src_corpus, padding='post')
dec_train = tf.keras.preprocessing.sequence.pad_sequences(tgt_corpus, padding='post')

# %%
# # 훈련 데이터와 검증 데이터로 분리하기
# enc_train, enc_val, dec_train, dec_val = train_test_split(enc_data, dec_data, test_size=0.05)

# %%
# enc, dec 의 seq_length는 달라도 상관없음.
print(enc_train.shape)
print(dec_train.shape)
# print(enc_val.shape)
# print(dec_val.shape)

# %%
# en_tokenizer.encode_as_pieces(eng_corpus[100])

# %% [markdown]
# # Step 3. 모델설계

# %% [markdown]
# ## Positional Encoding

# %%
# pos - 단어가 위치한 Time-step(각각의 토큰의 위치정보값이며 정수값을 의미)
# d_model - 모델의 Embedding 차원 수
# i - Encoding차원의 index

def positional_encoding(pos, d_model):
    def cal_angle(position, i):
        return position / np.power(10000, int(i)/d_model)  # np.power(a,b) > a^b(제곱)
    
    def get_posi_angle_vec(position):
        return [cal_angle(position, i) for i in range(d_model)]
    
    sinusoid_table = np.array([get_posi_angle_vec(pos_i) for pos_i in range(pos)])
    
    # 배열의 짝수 인덱스(2i)에는 사인 함수 적용
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])
    # 배열의 홀수 인덱스(2i+1)에는 코사인 함수 적용
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])
    
    return sinusoid_table

# %% [markdown]
# ## Multi-Head Attention

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model
        
        self.depth = d_model // self.num_heads
        
        self.W_q = tf.keras.layers.Dense(d_model)  # Linear Layer
        self.W_k = tf.keras.layers.Dense(d_model)
        self.W_v = tf.keras.layers.Dense(d_model)
        
        self.linear = tf.keras.layers.Dense(d_model)
        
    def scaled_dot_product_attention(self, Q, K, V, mask):
        d_k = tf.cast(K.shape[-1], tf.float32)
        
        # Scaled QK 값 구하기
        QK = tf.matmul(Q, K, transpose_b=True)
        scaled_qk = QK / tf.math.sqrt(d_k)
        
        if mask is not None:
            scaled_qk += (mask * -1e9)
        
        # 1. Attention Weights 값 구하기 -> attentions
        attentions = tf.nn.softmax(scaled_qk, axis=-1)
        # 2. Attention 값을 V에 곱하기 -> out
        out = tf.matmul(attentions, V)
        return out, attentions
    
    def split_heads(self, x):
        """
        Embedding된 입력을 head의 수로 분할하는 함수
        
        x: [ batch x length x emb ]
        return: [ batch x length x heads x self.depth ]
        """
        bsz = x.shape[0]
        split_x = tf.reshape(x, (bsz, -1, self.num_heads, self.depth))
        split_x = tf.transpose(split_x, perm=[0, 2, 1, 3])
        return split_x
    
    def combine_heads(self, x):
        """
        분할된 Embedding을 하나로 결합하는 함수
        
        x: [ batch x length x heads x self.depth ]
        return: [ batch x length x emb ]
        """
        bsz = x.shape[0]
        combined_x = tf.transpose(x, perm=[0, 2, 1, 3])
        combined_x = tf.reshape(combined_x, (bsz, -1, self.d_model))
        return combined_x
    
    def call(self, Q, K, V, mask):
        """
        Step 1: Linear_in(Q, K, V) -> WQ, WK, WV
        Step 2: Split Heads(WQ, WK, WV) -> WQ_split, WK_split, WV_split
        Step 3: Scaled Dot Product Attention(WQ_split, WK_split, WV_split)
                 -> out, attention_weights
        Step 4: Combine Heads(out) -> out
        Step 5: Linear_out(out) -> out
        """
        WQ = self.W_q(Q)
        WK = self.W_k(K)
        WV = self.W_v(V)
        
        WQ_splits = self.split_heads(WQ)
        WK_splits = self.split_heads(WK)
        WV_splits = self.split_heads(WV)
        
        out, attention_weights = self.scaled_dot_product_attention(
            WQ_splits, WK_splits, WV_splits, mask
        )
        
        out = self.combine_heads(out)
        out = self.linear(out)
        
        return out, attention_weights

# %% [markdown]
# ## Position-wise Feed-Forward Network

# %%
class PoswiseFeedForwardNet(tf.keras.layers.Layer):
    def __init__(self, d_model, d_ff):
        super(PoswiseFeedForwardNet, self).__init__()
        self.w_1 = tf.keras.layers.Dense(d_ff, activation='relu')
        self.w_2 = tf.keras.layers.Dense(d_model)

    def call(self, x):
        out = self.w_1(x)
        out = self.w_2(out)
            
        return out

print("슝=3")

# %% [markdown]
# d_ff 는 논문의 설명대로라면 2048 일 거고, d_model 은 512  [ batch x length x d_model ] 의 입력을 받아 w_1 이 2048차원으로 매핑하고 활성함수 ReLU를 적용한 후, 다시 w_2 를 통해 512차원으로 되돌리는 과정

# %% [markdown]
# ## Encoder 레이어 구현하기

# %%
class EncoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, n_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.enc_self_attn = MultiHeadAttention(d_model, n_heads)
        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)
        
        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        # Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        out, enc_attn = self.enc_self_attn(out, out, out, mask)
        out = self.do(out)
        out += residual*1 
        
        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_2(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual*1 
        
        return out, enc_attn

# %% [markdown]
# ## Decoder 레이어 구현하기

# %%
class DecoderLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(DecoderLayer, self).__init__()

        self.dec_self_attn = MultiHeadAttention(d_model, num_heads)
        self.enc_dec_attn = MultiHeadAttention(d_model, num_heads)

        self.ffn = PoswiseFeedForwardNet(d_model, d_ff)

        self.norm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.norm_3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        # Masked Multi-Head Attention
        residual = x
        out = self.norm_1(x)
        #out, dec_attn = self.dec_self_attn(out, out, out, causality_mask)
        out, dec_attn = self.dec_self_attn(out, out, out, padding_mask)
        out = self.do(out)
        out += residual
        
        # Multi-Head Attention
        residual = out
        out = self.norm_2(out)
        #out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, padding_mask)
        out, dec_enc_attn = self.enc_dec_attn(out, enc_out, enc_out, causality_mask)
        out = self.do(out)
        out += residual

        # Position-Wise Feed Forward Network
        residual = out
        out = self.norm_3(out)
        out = self.ffn(out)
        out = self.do(out)
        out += residual

        return out, dec_attn, dec_enc_attn

# %% [markdown]
# ## Encoder와 Decoder 클래스를 정의
# EncodeLayer 와 DecoderLayer 를 모두 정의했으니 이를 조립하는 것은 어렵지 않겠죠? 이를 이용해 Encoder와 Decoder 클래스를 정의합니다.

# %%
class Encoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Encoder, self).__init__()
        self.n_layers = n_layers
        self.enc_layers = [EncoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        self.do = tf.keras.layers.Dropout(dropout)
        
    def call(self, x, mask):
        out = x
        enc_attns = list()
        for i in range(self.n_layers):
            out, enc_attn = self.enc_layers[i](out, mask)
            enc_attns.append(enc_attn)
            
        return out, enc_attns

# %%
class Decoder(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, dropout):
        super(Decoder, self).__init__()
        self.n_layers = n_layers
        self.dec_layers = [DecoderLayer(d_model, n_heads, d_ff, dropout) for _ in range(n_layers)]
        
    def call(self, x, enc_out, causality_mask, padding_mask):
        out = x
        dec_attns = list()
        dec_enc_attns = list()
        for i in range(self.n_layers):
            out, dec_attn, dec_enc_attn = self.dec_layers[i](out, enc_out, causality_mask, padding_mask)
            dec_attns.append(dec_attn)
            dec_enc_attns.append(dec_enc_attn)
        
        return out, dec_attns, dec_enc_attns

# %% [markdown]
# ## Transformer 완성하기

# %%
class Transformer(tf.keras.Model):
    def __init__(self, n_layers, d_model, n_heads, d_ff, src_vocab_size, tgt_vocab_size,
                 pos_len, dropout=0.2, shared=True):
        super(Transformer, self).__init__()
        self.d_model = tf.cast(d_model, tf.float32)
        
        # 1. Embedding Layer 정의
        self.enc_emb = tf.keras.layers.Embedding(src_vocab_size, d_model)
        self.dec_emb = tf.keras.layers.Embedding(tgt_vocab_size, d_model)
        
        # 2. Positional Encoding 정의
        self.pos_encoding = positional_encoding(pos_len, d_model)
        # 6. Dropout 정의
        self.do = tf.keras.layers.Dropout(dropout)
        
        # 3. Encoder / Decoder 정의
        self.encoder = Encoder(n_layers, d_model, n_heads, d_ff, dropout)
        self.decoder = Decoder(n_layers, d_model, n_heads, d_ff, dropout)
        
        # 4. Output Linear 정의
        self.fc = tf.keras.layers.Dense(tgt_vocab_size)
        
        # 5. Shared Weights
        self.shared = shared
        
        if shared:
            self.fc.set_weights(tf.transpose(self.dec_emb.weights))
        
        
    def embedding(self, emb, x):
        """
        입력된 정수 배열을 Embedding + Pos Encoding
        + Shared일 경우 Scaling 작업 포함

        x: [ batch x length ]
        return: [ batch x length x emb ]
        """
        seq_len = x.shape[1]
        out = emb(x)
        
        if self.shared:
            out *= tf.math.sqrt(self.d_model)
        
        out += self.pos_encoding[np.newaxis, ...][:, :seq_len, :]
        out = self.do(out)
        
        return out
    
    def call(self, enc_in, dec_in, enc_mask, causality_mask, dec_mask):
        # Step 1: Embedding(enc_in, dec_in) -> enc_in, dec_in
        enc_in = self.embedding(self.enc_emb, enc_in)
        dec_in = self.embedding(self.dec_emb, dec_in)
        
        # Step 2: Encoder(enc_in, enc_mask) -> enc_out, enc_attns
        enc_out, enc_attns = self.encoder(enc_in, enc_mask)

        # Step 3: Decoder(dec_in, enc_out, mask) -> dec_out, dec_attns, dec_enc_attns
        dec_out, dec_attns, dec_enc_attns = self.decoder(dec_in, enc_out, causality_mask, dec_mask)
        
        # Step 4: Out Linear(dec_out) -> logits
        logits = self.fc(dec_out)
        
        return logits, enc_attns, dec_attns, dec_enc_attns

# %% [markdown]
# ## Mask

# %%
# Attention을 할 때에 <PAD> 토큰에도 Attention을 주는 것을 방지해 주는 역할
def generate_padding_mask(seq):
    seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
    return seq[:, tf.newaxis, tf.newaxis, :]

def generate_causality_mask(src_len, tgt_len):
    mask = 1 - np.cumsum(np.eye(src_len, tgt_len), 0)
    return tf.cast(mask, tf.float32)

def generate_masks(src, tgt):
    enc_mask = generate_padding_mask(src)
    dec_mask = generate_padding_mask(tgt)

    dec_enc_causality_mask = generate_causality_mask(tgt.shape[1], src.shape[1])
    dec_enc_mask = tf.maximum(enc_mask, dec_enc_causality_mask)

    dec_causality_mask = generate_causality_mask(tgt.shape[1], tgt.shape[1])
    dec_mask = tf.maximum(dec_mask, dec_causality_mask)

    return enc_mask, dec_enc_mask, dec_mask

# %% [markdown]
# # Step 4. 훈련하기

# %%
transformer = Transformer(
    n_layers=6,
    d_model=512,
    n_heads=8,
    d_ff=2048,
    src_vocab_size=SRC_VOCAB_SIZE,
    tgt_vocab_size=TGT_VOCAB_SIZE,
    pos_len=200,
    dropout=0.1,
    shared=True
)

# %% [markdown]
# ##  Learning Rate Scheduler를 선언하고, 이를 포함하는 Adam Optimizer를 선언

# %%
class LearningRateScheduler(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(LearningRateScheduler, self).__init__()
        self.d_model = d_model
        self.warmup_steps = warmup_steps
    
    def __call__(self, step):
        arg1 = step ** -0.5
        arg2 = step * (self.warmup_steps ** -1.5)
        
        return (self.d_model ** -0.5) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = LearningRateScheduler(512)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# %% [markdown]
# ## Loss 함수를 정의

# %%
# Loss 함수 정의
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    # Masking 되지 않은 입력의 개수로 Scaling하는 과정
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %% [markdown]
# ## train_step 함수를 정의

# %%
@tf.function()
def train_step(src, tgt, model, optimizer):
    gold = tgt[:, 1:]
        
    enc_mask, dec_enc_mask, dec_mask = generate_masks(src, tgt)

    # 계산된 loss에 tf.GradientTape()를 적용해 학습을 진행합니다.
    with tf.GradientTape() as tape:
        predictions, enc_attns, dec_attns, dec_enc_attns = model(src, tgt, enc_mask, dec_enc_mask, dec_mask)
        loss = loss_function(gold, predictions[:, :-1])

    # 최종적으로 optimizer.apply_gradients()가 사용됩니다. 
    gradients = tape.gradient(loss, model.trainable_variables)    
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))
    
    return loss, enc_attns, dec_attns, dec_enc_attns

# %%
ckpt = tf.train.Checkpoint(step = tf.Variable(1), optimizer = optimizer , transformer = transformer)
manager = tf.train.CheckpointManager(ckpt, './tf_ckpts_gd12_r1',max_to_keep=2)

# %% [markdown]
# ## Attention 시각화 함수

# %%
# Attention 시각화 함수
def visualize_attention(src, tgt, enc_attns, dec_attns, dec_enc_attns):
    def draw(data, ax, x="auto", y="auto"):
        import seaborn
        seaborn.heatmap(data, 
                        square=True,
                        vmin=0.0, vmax=1.0, 
                        cbar=False, ax=ax,
                        xticklabels=x,
                        yticklabels=y)
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Encoder Layer", layer + 1)
        for h in range(4):
            draw(enc_attns[layer][0, h, :len(src), :len(src)], axs[h], src, src)
        plt.show()
        
    for layer in range(0, 2, 1):
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        print("Decoder Self Layer", layer+1)
        for h in range(4):
            draw(dec_attns[layer][0, h, :len(tgt), :len(tgt)], axs[h], tgt, tgt)
        plt.show()

        print("Decoder Src Layer", layer+1)
        fig, axs = plt.subplots(1, 4, figsize=(20, 10))
        for h in range(4):
            draw(dec_enc_attns[layer][0, h, :len(tgt), :len(src)], axs[h], src, tgt)
        plt.show()

# %% [markdown]
# ## 번역생성함수

# %%
# 번역 생성 함수
def evaluate(sentence, model, src_tokenizer, tgt_tokenizer):
    sentence = preprocess_sentence(sentence)
    pieces = src_tokenizer.encode_as_pieces(sentence)
    tokens = src_tokenizer.encode_as_ids(sentence)

    _input = tf.keras.preprocessing.sequence.pad_sequences([tokens], maxlen=enc_train.shape[-1], padding='post')

    ids = []
    output = tf.expand_dims([tgt_tokenizer.bos_id()], 0)
    for i in range(dec_train.shape[-1]):
        enc_padding_mask, combined_mask, dec_padding_mask = generate_masks(_input, output)
        

        predictions, enc_attns, dec_attns, dec_enc_attns = model(_input, output, enc_padding_mask, combined_mask, dec_padding_mask)
        
        predicted_id = tf.argmax(tf.math.softmax(predictions, axis=-1)[0, -1]).numpy().item()
        if tgt_tokenizer.eos_id() == predicted_id:
            result = tgt_tokenizer.decode_ids(ids)
            return pieces, result, enc_attns, dec_attns, dec_enc_attns

        ids.append(predicted_id)
        output = tf.concat([output, tf.expand_dims([predicted_id], 0)], axis=-1)
    result = tgt_tokenizer.decode_ids(ids)
    return pieces, result, enc_attns, dec_attns, dec_enc_attns

# %%
# 번역 생성 및 Attention 시각화 결합
def translate(sentence, model, src_tokenizer, tgt_tokenizer, plot_attention=False):
    pieces, result, enc_attns, dec_attns, dec_enc_attns = evaluate(sentence, model, src_tokenizer, tgt_tokenizer)
    
    print('Input: %s' % (sentence))
    print('Predicted translation: {}'.format(result))

    if plot_attention:
        visualize_attention(pieces, result.split(), enc_attns, dec_attns, dec_enc_attns)
  
    return result

# %%
examples = [
    "How was your day? I was the best.",
    "Take your time, please.",
    "I’m about to leave. Please hold for a moment.",
    "Have you heard of it?"
]

# %% [markdown]
# ## 학습

# %%
# 학습
EPOCHS = 5
BATCH_SIZE = 64

def train_and_checkpoint(transformer, manager, EPOCHS):
    ckpt.restore(manager.latest_checkpoint)
    if manager.latest_checkpoint:
        print("Restored from {}".format(manager.latest_checkpoint))
    
    else:
        print("Initializing from scratch.")


    for epoch in range(EPOCHS):
        total_loss = 0

        idx_list = list(range(0, enc_train.shape[0], BATCH_SIZE))
        random.shuffle(idx_list)
        t = tqdm(idx_list)

        for (batch, idx) in enumerate(t):
            batch_loss, enc_attns, dec_attns, dec_enc_attns = train_step(enc_train[idx:idx+BATCH_SIZE],
                                                                         dec_train[idx:idx+BATCH_SIZE],
                                                                         transformer,
                                                                         optimizer)

            total_loss += batch_loss

            t.set_description_str('Epoch %2d' % (epoch + 1))
            t.set_postfix_str('Loss %.4f' % (total_loss.numpy() / (batch + 1)))
      
      
        # 매 Epoch 마다 제시된 예문에 대한 번역 생성
        for example in examples:
            translate(example, transformer, en_tokenizer, ko_tokenizer)
            
 
        if int(ckpt.step) % 2 == 0:
            save_path = manager.save()
            print("Saved checkpoint for step {}: {}".format(int(ckpt.step), save_path))

# %%
train_and_checkpoint(transformer, manager, EPOCHS )

# %%
for example in examples:
    translate(example, transformer, en_tokenizer, ko_tokenizer)

# %% [markdown]
# # Step 5. 평가

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

def eval_bleu_single(model, src_sentence, tgt_sentence, en_tokenizer, ko_tokenizer, verbose=True):
    src_tokens = en_tokenizer.encode_as_ids(src_sentence)
    tgt_tokens = ko_tokenizer.encode_as_ids(tgt_sentence)

    if (len(src_tokens) > 120): return None
    if (len(tgt_tokens) > 100): return None

    reference = tgt_sentence.split()
    candidate = translate(src_sentence, model, en_tokenizer, ko_tokenizer).split()

    score = sentence_bleu([reference], candidate,
                          smoothing_function=SmoothingFunction().method1)

    if verbose:
        print("Source Sentence: ", src_sentence)
        print("Model Prediction: ", candidate)
        print("Real: ", reference)
        print("Score: %lf\n" % score)
        
    return score

# %%
# single test
test_idx = 2

eval_bleu_single(transformer, 
                 eng_corpus_test[test_idx], 
                 kor_corpus_test[test_idx], 
                 en_tokenizer, 
                 ko_tokenizer, 
                 verbose=True)

# %%
def eval_bleu(model, src_sentences, tgt_sentence, en_tokenizer, ko_tokenizer, verbose=True):
    total_score = 0.0
    sample_size = len(src_sentences)
    
    for idx in tqdm(range(sample_size)):
        score = eval_bleu_single(model, src_sentences[idx], tgt_sentence[idx], en_tokenizer, ko_tokenizer, verbose)
        if not score: continue
        
        total_score += score
    
    print("Num of Sample:", sample_size)
    print("Total Score:", total_score / sample_size)

# %%
len(eng_corpus_test)

# %%
eval_bleu(transformer, eng_corpus_test[:100], kor_corpus_test[:100], en_tokenizer, ko_tokenizer, verbose=False)

# %%
# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# predictions = [["I", "have", "thirty", "six", "years"]] 
# references = [
#     [["I", "am", "thirty", "six", "years", "old"], ["I", "am", "thirty", "six"]]
# ]
# bleu.compute(predictions=predictions, references=references)

# # Bleu example
# from datasets import load_metric

# bleu = load_metric("bleu")
# #bleu = load_metric('sacrebleu')

# reference = [kor_corpus_test.split()]
# predictions = [translate(eng_corpus_test, transformer, en_tokenizer, ko_tokenizer).split()]

# bleu.compute(predictions=predictions, references=reference)

# %%
# import matplotlib as mpl
# import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
 
# import matplotlib.font_manager as fm

# fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
# font = fm.FontProperties(fname=fontpath, size=9)
# plt.rc('font', family='NanumBarunGothic') 
# # mpl.font_manager._rebuild()

# %%
# 매 Epoch 마다 제시된 예문에 대한 번역 생성시각화
# for example in examples:
#     translate(example, transformer, en_tokenizer, ko_tokenizer, plot_attention=True)
